# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaAmirtharaj/cs249_final_project/blob/main/smoke_detection_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Import

# %% [markdown]
# ## Prepare Data
#
#
# To train a TensorFlow2 Object Detection Model, we need TFRecord and label_map files. Roboflow creates these files for us!
#
# Because we need one TFRecord file for our training data, and one TFRecord file for our test data, we'll split the dataset into "train" and "test".
#
# To create a dataset in Roboflow and generate TFRecords, follow [this step-by-step guide](https://blog.roboflow.ai/getting-started-with-roboflow/). On export, select "Tensorflow TFRecord" for the first link and "COCO JSON" as the second link below.

# %% [markdown]
# ![](https://i.imgur.com/ZwMdcbY.png)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kurHDAP4tAun3nyyYi4d")
project = rf.workspace("wildfire-xpwrf").project("wildfire-4tdl8")

# Specify the desired version of the dataset and the output directory
output_directory = "/content/Wildfire"
dataset = project.version(2).download("tfrecord", output_directory)
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.12-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.1 MB/s eta 0:00:00
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.9 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.9 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.16.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.8 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.45.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.4)
# Installing collected packages: python-magic, python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.12 supervision-0.16.0
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/Wildfire to tfrecord:: 100%|██████████| 33180/33180 [00:00<00:00, 64593.58it/s]
# Extracting Dataset Version Zip to /content/Wildfire in tfrecord:: 100%|██████████| 11/11 [00:00<00:00, 176.46it/s]

# %% [markdown]
# # 2. Train

# %% [markdown]
# _Note that this section is based on the [MobileNetSSDv2 Notebook](https://colab.research.google.com/drive/1wTMIrJhYsQdq_u7ROOkf0Lu_fsX5Mu8a). This is because TensorFlow Lite is independent of the model used, so we're picking a simple and lightweight solution._

# %% [markdown]
# ## Configs and Hyperparameters
#
# Support a variety of models, you can find more pretrained model from [Tensorflow detection model zoo: COCO-trained models](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md#coco-trained-models), as well as their pipline config files in [object_detection/samples/configs/](https://github.com/tensorflow/models/tree/master/research/object_detection/samples/configs).

# %%
# If you forked the repo, you can replace the link.
repo_url = 'https://github.com/roboflow-ai/tensorflow-object-detection-faster-rcnn'

# Number of training steps - 1000 will train very quickly, but more steps will increase accuracy.
num_steps = 1000  # 200000 to improve

# Number of evaluation steps.
num_eval_steps = 50

MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8',
        'pipeline_file': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config',
        'batch_size': 12
    },
    'faster_rcnn': { # Update to make compatible with TF2
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu',
        'pipeline_file': 'faster_rcnn_resnet50_v1_640x640_coco17_tpu-8.config',
        'batch_size': 12
    },
    'efficientdet': { # Update to make compatible with TF2
        'model_name': 'ssd_efficientdet_d4_1024x1024_coco17_tpu-32',
        'pipeline_file': 'ssd_efficientdet_d4_1024x1024_coco17_tpu-32.config',
        'batch_size': 8
    },
}


# Pick the model you want to use
# Select a model in `MODELS_CONFIG`.
selected_model = 'ssd_mobilenet_v2'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

# %% [markdown]
# ## Clone the `tensorflow-object-detection` repository or your fork.

# %%
import os

# %cd /content

repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))

# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# /content
# Cloning into 'tensorflow-object-detection-faster-rcnn'...
# remote: Enumerating objects: 885, done.
# remote: Total 885 (delta 0), reused 0 (delta 0), pack-reused 885
# Receiving objects: 100% (885/885), 24.83 MiB | 31.51 MiB/s, done.
# Resolving deltas: 100% (428/428), done.
# /content/tensorflow-object-detection-faster-rcnn
# Already up to date.

# %% [markdown]
# ## Install required packages

# %%
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git

# !pip install tf_slim

# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install tensorflow_io

# !pip install tf-models-official

# TF 2.13.0 is the only compatible version
# !pip uninstall -y tensorflow
# !pip install tensorflow==2.13.0

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf_slim) (1.4.0)
# E: Unable to locate package python-pil
# E: Unable to locate package python-lxml
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 54.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.34.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io) (0.34.0)
# Installing collected packages: tensorflow_io
# Successfully installed tensorflow_io-0.34.0
# Collecting tf-models-official
#   Downloading tf_models_official-2.15.0-py2.py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (3.0.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (9.4.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (2.84.0)
# Collecting immutabledict (from tf-models-official)
#   Downloading immutabledict-4.0.0-py3-none-any.whl (4.5 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.5.16)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.23.5)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.8.0.74)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.5.3)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (9.0.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (2.0.7)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (6.0.1)
# Collecting sacrebleu (from tf-models-official)
#   Downloading sacrebleu-2.3.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.11.4)
# Collecting sentencepiece (from tf-models-official)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.1 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.16.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.9.3)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (0.15.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official)
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 31.3 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.15.0 (from tf-models-official)
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 69.5 MB/s eta 0:00:00
# Collecting tensorflow~=2.15.0 (from tf-models-official)
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: tf-slim>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (4.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->tf-models-official) (2023.3.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.59.3)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow~=2.15.0->tf-models-official)
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 94.1 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow~=2.15.0->tf-models-official)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 50.7 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0 (from tensorflow~=2.15.0->tf-models-official)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.5 MB/s eta 0:00:00
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official) (0.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (2.4.7)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (4.9)
# Collecting portalocker (from sacrebleu->tf-models-official)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (0.9.0)
# Collecting colorama (from sacrebleu->tf-models-official)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (4.9.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official) (1.2.2)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (0.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (1.5.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (1.14.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.15.0->tf-models-official) (0.42.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (6.1.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (3.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official) (1.61.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official) (5.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official) (2.10)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (3.2.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (3.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle>=1.3.9->tf-models-official) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (3.2.2)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=9e7a1e1819321f809d7b431e962c82ffcdeffaf221f581e313c90eb78f2593fd
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: sentencepiece, tensorflow-model-optimization, tensorflow-estimator, portalocker, keras, immutabledict, colorama, sacrebleu, seqeval, tensorboard, tensorflow, tensorflow-text, tf-models-official
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0

# %%
# Verify we are using Tensorflow 2.13.0
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.13.0

# %% [markdown]
# ## Prepare `tfrecord` files
#
# Roboflow automatically creates our TFRecord and label_map files that we need!
#
# **Generating your own TFRecords the only step you need to change for your own custom dataset.**
#
# Because we need one TFRecord file for our training data, and one TFRecord file for our test data, we'll create two separate datasets in Roboflow and generate one set of TFRecords for each.
#
# To create a dataset in Roboflow and generate TFRecords, follow [this step-by-step guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %%
# %cd /content/tensorflow-object-detection-faster-rcnn/data
# Out:
# /content/tensorflow-object-detection-faster-rcnn/data

# %%
# !cp -r /content/Wildfire/train/ /content/tensorflow-object-detection-faster-rcnn/data/
# !cp -r /content/Wildfire/test/ /content/tensorflow-object-detection-faster-rcnn/data/

# %%
# training set
# %ls train
# Out:
# fire_label_map.pbtxt  fire.tfrecord

# %%
# test set
# %ls test
# Out:
# fire_label_map.pbtxt  fire.tfrecord

# %%
test_record_fname = '/content/tensorflow-object-detection-faster-rcnn/data/test/fire.tfrecord'
train_record_fname = '/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord'
label_map_pbtxt_fname = '/content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt'

# %% [markdown]
# ## Download base model

# %%
# %cd /content/models/research

import os
import shutil
import glob
import urllib.request
import tarfile
MODEL_FILE = MODEL + '.tar.gz'
print(MODEL_FILE)
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/'
print(DOWNLOAD_BASE)
DEST_DIR = '/content/models/research/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)
# Out:
# /content/models/research
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# http://download.tensorflow.org/models/object_detection/tf2/20200711/

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/models/research/pretrained_model
# total 24K
# drwxr-x---  4 345018 89939 4.0K Jul 11  2020 .
# drwxr-xr-x 23 root   root  4.0K Dec  5 03:49 ..
# drwxr-x---  2 345018 89939 4.0K Jul 10  2020 checkpoint
# -rw-r-----  1 345018 89939 4.5K Jul 11  2020 pipeline.config
# drwxr-x---  3 345018 89939 4.0K Jul 10  2020 saved_model

# %%
import os

directory_path = '/content/models/research/pretrained_model/checkpoint'
os.listdir(directory_path)
# Out:
# ['ckpt-0.index', 'checkpoint', 'ckpt-0.data-00000-of-00001']

# %%
# Fix checkpoint naming scheme
import os
import glob

directory_path = '/content/models/research/pretrained_model/checkpoint'

# Loop through all files that start with 'model.ckpt-1.'
for filepath in glob.glob(os.path.join(directory_path, 'ckpt-0.*')):
    base_directory, filename = os.path.split(filepath)
    file_extension = filename.split('.', 2)[-1]

    # Construct the new filename
    new_filename = 'model.ckpt.' + file_extension

    # Construct the full path for the new file
    new_filepath = os.path.join(base_directory, new_filename)

    # Rename the file
    os.rename(filepath, new_filepath)
    print(f'Renamed {filepath} to {new_filepath}')
# Out:
# Renamed /content/models/research/pretrained_model/checkpoint/ckpt-0.index to /content/models/research/pretrained_model/checkpoint/model.ckpt.index
# Renamed /content/models/research/pretrained_model/checkpoint/ckpt-0.data-00000-of-00001 to /content/models/research/pretrained_model/checkpoint/model.ckpt.data-00000-of-00001

# %%
# Verify naming scheme of checkpoints
import os

directory_path = '/content/models/research/pretrained_model/checkpoint'
os.listdir(directory_path)
# Out:
# ['model.ckpt.data-00000-of-00001', 'checkpoint', 'model.ckpt.index']

# %% [markdown]
# ## Configuring a Training Pipeline

# %%
import os
pipeline_fname = os.path.join('/content/models/research/object_detection/configs/tf2/', pipeline_file)
print(pipeline_file)

assert os.path.isfile(pipeline_fname), '`{}` not exist'.format(pipeline_fname)
# Out:
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config

# %%
def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

# %%
import re

train_record = "/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord"
train_label_map = "/content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt"

test_record = "/content/tensorflow-object-detection-faster-rcnn/data/test/fire.tfrecord"
test_label_map = "/content/tensorflow-object-detection-faster-rcnn/data/test/fire_label_map.pbtxt"

checkpoint = "/content/models/research/pretrained_model/checkpoint/model.ckpt"

num_classes = get_num_classes(label_map_pbtxt_fname)

with open(pipeline_fname) as f:
    s = f.read()
with open(pipeline_fname, 'w') as f:

    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(checkpoint), s)

    s = re.sub('fine_tune_checkpoint_type: ".*?"',
               'fine_tune_checkpoint_type: "detection"', s)

    # label_map_path
    s = re.sub(r'(train_input_reader: {[\s\S]*?label_map_path: ")[^"]*(")',
               r'\1{}\2'.format(train_label_map), s)
    s = re.sub(r'(eval_input_reader: {[\s\S]*?label_map_path: ")[^"]*(")',
               r'\1{}\2'.format(test_label_map), s)

    # tfrecord paths
    s = re.sub(
        r'(train_input_reader: {\s+label_map_path: ".*?"\s+tf_record_input_reader {\s+input_path: ").*?(")',
        r'\1{}\2'.format(train_record), s)
    s = re.sub(
        r'(eval_input_reader: \{\s+label_map_path: ".*?"\s+shuffle: \w+\s+num_epochs: \d+\s+tf_record_input_reader \{\s+input_path: ").*?(")',
        r'\1{}\2'.format(test_record), s, flags=re.DOTALL)


    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)

    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    f.write(s)

# %%
# !cat {pipeline_fname}
# Out:
# # SSD with Mobilenet v2 FPN-lite (go/fpn-lite) feature extractor, shared box
# # predictor and focal loss (a mobile version of Retinanet).
# # Retinanet: see Lin et al, https://arxiv.org/abs/1708.02002
# # Trained on COCO, initialized from Imagenet classification checkpoint
# # Train on TPU-8
# #
# # Achieves 22.2 mAP on COCO17 Val
#
# model {
#   ssd {
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#     num_classes: 1
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     encode_background_as_zeros: true
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: [1.0, 2.0, 0.5]
#         scales_per_octave: 2
#       }
#     }
#     image_resizer {
#       fixed_shape_resizer {
#         height: 320
#         width: 320
#       }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         depth: 128
#         class_prediction_bias_init: -4.6
#         conv_hyperparams {
#           activation: RELU_6,
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               stddev: 0.01
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             scale: true,
#             decay: 0.997,
#             epsilon: 0.001,
#           }
#         }
#         num_layers_before_predictor: 4
#         share_prediction_tower: true
#         use_depthwise: true
#         kernel_size: 3
#       }
#     }
#     feature_extractor {
#       type: 'ssd_mobilenet_v2_fpn_keras'
#       use_depthwise: true
#       fpn {
#         min_level: 3
#         max_level: 7
#         additional_layer_depth: 128
#       }
#       min_depth: 16
#       depth_multiplier: 1.0
#       conv_hyperparams {
#         activation: RELU_6,
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           random_normal_initializer {
#             stddev: 0.01
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           scale: true,
#           decay: 0.997,
#           epsilon: 0.001,
#         }
#       }
#       override_base_feature_extractor_hyperparams: true
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid_focal {
#           alpha: 0.25
#           gamma: 2.0
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     normalize_loc_loss_by_codesize: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   fine_tune_checkpoint_version: V2
#   fine_tune_checkpoint: "/content/models/research/pretrained_model/checkpoint/model.ckpt"
#   fine_tune_checkpoint_type: "detection"
#   batch_size: 12
#   sync_replicas: true
#   startup_delay_steps: 0
#   replicas_to_aggregate: 8
#   num_steps: 50000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     random_crop_image {
#       min_object_covered: 0.0
#       min_aspect_ratio: 0.75
#       max_aspect_ratio: 3.0
#       min_area: 0.75
#       max_area: 1.0
#       overlap_thresh: 0.0
#     }
#   }
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         cosine_decay_learning_rate {
#           learning_rate_base: .08
#           total_steps: 50000
#           warmup_learning_rate: .026666
#           warmup_steps: 1000
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
# }
#
# train_input_reader: {
#   label_map_path: "/content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord"
#   }
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
#
# eval_input_reader: {
#   label_map_path: "/content/tensorflow-object-detection-faster-rcnn/data/test/fire_label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/content/tensorflow-object-detection-faster-rcnn/data/test/fire.tfrecord"
#   }
# }

# %%
model_dir = '../../../content/training/'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# ## Run Tensorboard(Optional)

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2023-12-05 03:50:39--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 54.237.133.81, 18.205.222.128, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  12.7MB/s    in 1.0s
#
# 2023-12-05 03:50:41 (12.7 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = model_dir
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %% [markdown]
# ### Get Tensorboard link

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://ec36-34-32-157-240.ngrok.io

# %% [markdown]
# ## Train the model

# %%
# !pip install lvis
# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_fname} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# Streaming output truncated to the last 5000 lines.
#  'Loss/regularization_loss': 0.12682508,
#  'Loss/total_loss': 0.260125,
#  'learning_rate': 0.07558186}
# I1205 04:15:10.510699 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.076756515,
#  'Loss/localization_loss': 0.056543414,
#  'Loss/regularization_loss': 0.12682508,
#  'Loss/total_loss': 0.260125,
#  'learning_rate': 0.07558186}
# INFO:tensorflow:Step 8500 per-step time 0.156s
# I1205 04:15:26.091463 138735047218304 model_lib_v2.py:705] Step 8500 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.081794254,
#  'Loss/localization_loss': 0.037842024,
#  'Loss/regularization_loss': 0.12646818,
#  'Loss/total_loss': 0.24610446,
#  'learning_rate': 0.07546397}
# I1205 04:15:26.091770 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.081794254,
#  'Loss/localization_loss': 0.037842024,
#  'Loss/regularization_loss': 0.12646818,
#  'Loss/total_loss': 0.24610446,
#  'learning_rate': 0.07546397}
# INFO:tensorflow:Step 8600 per-step time 0.158s
# I1205 04:15:41.867041 138735047218304 model_lib_v2.py:705] Step 8600 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.075871915,
#  'Loss/localization_loss': 0.036228847,
#  'Loss/regularization_loss': 0.12599204,
#  'Loss/total_loss': 0.23809281,
#  'learning_rate': 0.075344615}
# I1205 04:15:41.867388 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.075871915,
#  'Loss/localization_loss': 0.036228847,
#  'Loss/regularization_loss': 0.12599204,
#  'Loss/total_loss': 0.23809281,
#  'learning_rate': 0.075344615}
# INFO:tensorflow:Step 8700 per-step time 0.158s
# I1205 04:15:57.684443 138735047218304 model_lib_v2.py:705] Step 8700 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.059187107,
#  'Loss/localization_loss': 0.027095724,
#  'Loss/regularization_loss': 0.12560773,
#  'Loss/total_loss': 0.21189056,
#  'learning_rate': 0.07522382}
# I1205 04:15:57.684760 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.059187107,
#  'Loss/localization_loss': 0.027095724,
#  'Loss/regularization_loss': 0.12560773,
#  'Loss/total_loss': 0.21189056,
#  'learning_rate': 0.07522382}
# INFO:tensorflow:Step 8800 per-step time 0.156s
# I1205 04:16:13.235720 138735047218304 model_lib_v2.py:705] Step 8800 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.10951075,
#  'Loss/localization_loss': 0.062847786,
#  'Loss/regularization_loss': 0.12519203,
#  'Loss/total_loss': 0.29755056,
#  'learning_rate': 0.07510157}
# I1205 04:16:13.236026 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.10951075,
#  'Loss/localization_loss': 0.062847786,
#  'Loss/regularization_loss': 0.12519203,
#  'Loss/total_loss': 0.29755056,
#  'learning_rate': 0.07510157}
# INFO:tensorflow:Step 8900 per-step time 0.158s
# I1205 04:16:29.028990 138735047218304 model_lib_v2.py:705] Step 8900 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.054330204,
#  'Loss/localization_loss': 0.03480345,
#  'Loss/regularization_loss': 0.1247351,
#  'Loss/total_loss': 0.21386875,
#  'learning_rate': 0.074977875}
# I1205 04:16:29.029318 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.054330204,
#  'Loss/localization_loss': 0.03480345,
#  'Loss/regularization_loss': 0.1247351,
#  'Loss/total_loss': 0.21386875,
#  'learning_rate': 0.074977875}
# INFO:tensorflow:Step 9000 per-step time 0.155s
# I1205 04:16:44.569407 138735047218304 model_lib_v2.py:705] Step 9000 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.0802823,
#  'Loss/localization_loss': 0.04449343,
#  'Loss/regularization_loss': 0.12429349,
#  'Loss/total_loss': 0.24906921,
#  'learning_rate': 0.07485275}
# I1205 04:16:44.569927 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.0802823,
#  'Loss/localization_loss': 0.04449343,
#  'Loss/regularization_loss': 0.12429349,
#  'Loss/total_loss': 0.24906921,
#  'learning_rate': 0.07485275}
# INFO:tensorflow:Step 9100 per-step time 0.167s
# I1205 04:17:01.229140 138735047218304 model_lib_v2.py:705] Step 9100 per-step time 0.167s
# INFO:tensorflow:{'Loss/classification_loss': 0.078129984,
#  'Loss/localization_loss': 0.033387892,
#  'Loss/regularization_loss': 0.12393697,
#  'Loss/total_loss': 0.23545486,
#  'learning_rate': 0.07472619}
# I1205 04:17:01.229469 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.078129984,
#  'Loss/localization_loss': 0.033387892,
#  'Loss/regularization_loss': 0.12393697,
#  'Loss/total_loss': 0.23545486,
#  'learning_rate': 0.07472619}
# INFO:tensorflow:Step 9200 per-step time 0.156s
# I1205 04:17:16.858221 138735047218304 model_lib_v2.py:705] Step 9200 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.1059394,
#  'Loss/localization_loss': 0.05734983,
#  'Loss/regularization_loss': 0.12364906,
#  'Loss/total_loss': 0.2869383,
#  'learning_rate': 0.07459819}
# I1205 04:17:16.858541 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.1059394,
#  'Loss/localization_loss': 0.05734983,
#  'Loss/regularization_loss': 0.12364906,
#  'Loss/total_loss': 0.2869383,
#  'learning_rate': 0.07459819}
# INFO:tensorflow:Step 9300 per-step time 0.155s
# I1205 04:17:32.311608 138735047218304 model_lib_v2.py:705] Step 9300 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.07268903,
#  'Loss/localization_loss': 0.046782997,
#  'Loss/regularization_loss': 0.123273134,
#  'Loss/total_loss': 0.24274516,
#  'learning_rate': 0.074468784}
# I1205 04:17:32.311916 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07268903,
#  'Loss/localization_loss': 0.046782997,
#  'Loss/regularization_loss': 0.123273134,
#  'Loss/total_loss': 0.24274516,
#  'learning_rate': 0.074468784}
# INFO:tensorflow:Step 9400 per-step time 0.156s
# I1205 04:17:47.868402 138735047218304 model_lib_v2.py:705] Step 9400 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.10314175,
#  'Loss/localization_loss': 0.03813527,
#  'Loss/regularization_loss': 0.12287507,
#  'Loss/total_loss': 0.26415208,
#  'learning_rate': 0.074337944}
# I1205 04:17:47.868703 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.10314175,
#  'Loss/localization_loss': 0.03813527,
#  'Loss/regularization_loss': 0.12287507,
#  'Loss/total_loss': 0.26415208,
#  'learning_rate': 0.074337944}
# INFO:tensorflow:Step 9500 per-step time 0.155s
# I1205 04:18:03.416180 138735047218304 model_lib_v2.py:705] Step 9500 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.069876134,
#  'Loss/localization_loss': 0.024092147,
#  'Loss/regularization_loss': 0.122427784,
#  'Loss/total_loss': 0.21639606,
#  'learning_rate': 0.074205704}
# I1205 04:18:03.416518 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.069876134,
#  'Loss/localization_loss': 0.024092147,
#  'Loss/regularization_loss': 0.122427784,
#  'Loss/total_loss': 0.21639606,
#  'learning_rate': 0.074205704}
# INFO:tensorflow:Step 9600 per-step time 0.155s
# I1205 04:18:18.899511 138735047218304 model_lib_v2.py:705] Step 9600 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.09229467,
#  'Loss/localization_loss': 0.035796322,
#  'Loss/regularization_loss': 0.12198772,
#  'Loss/total_loss': 0.2500787,
#  'learning_rate': 0.07407206}
# I1205 04:18:18.899819 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.09229467,
#  'Loss/localization_loss': 0.035796322,
#  'Loss/regularization_loss': 0.12198772,
#  'Loss/total_loss': 0.2500787,
#  'learning_rate': 0.07407206}
# INFO:tensorflow:Step 9700 per-step time 0.155s
# I1205 04:18:34.402557 138735047218304 model_lib_v2.py:705] Step 9700 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.055714305,
#  'Loss/localization_loss': 0.026901005,
#  'Loss/regularization_loss': 0.12151504,
#  'Loss/total_loss': 0.20413035,
#  'learning_rate': 0.073937014}
# I1205 04:18:34.402865 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.055714305,
#  'Loss/localization_loss': 0.026901005,
#  'Loss/regularization_loss': 0.12151504,
#  'Loss/total_loss': 0.20413035,
#  'learning_rate': 0.073937014}
# INFO:tensorflow:Step 9800 per-step time 0.156s
# I1205 04:18:50.011352 138735047218304 model_lib_v2.py:705] Step 9800 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.08506434,
#  'Loss/localization_loss': 0.04029869,
#  'Loss/regularization_loss': 0.12115517,
#  'Loss/total_loss': 0.2465182,
#  'learning_rate': 0.07380057}
# I1205 04:18:50.011706 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08506434,
#  'Loss/localization_loss': 0.04029869,
#  'Loss/regularization_loss': 0.12115517,
#  'Loss/total_loss': 0.2465182,
#  'learning_rate': 0.07380057}
# INFO:tensorflow:Step 9900 per-step time 0.158s
# I1205 04:19:05.788414 138735047218304 model_lib_v2.py:705] Step 9900 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.081648365,
#  'Loss/localization_loss': 0.038095187,
#  'Loss/regularization_loss': 0.120709896,
#  'Loss/total_loss': 0.24045345,
#  'learning_rate': 0.073662736}
# I1205 04:19:05.788781 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.081648365,
#  'Loss/localization_loss': 0.038095187,
#  'Loss/regularization_loss': 0.120709896,
#  'Loss/total_loss': 0.24045345,
#  'learning_rate': 0.073662736}
# INFO:tensorflow:Step 10000 per-step time 0.155s
# I1205 04:19:21.298919 138735047218304 model_lib_v2.py:705] Step 10000 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.07960798,
#  'Loss/localization_loss': 0.03548854,
#  'Loss/regularization_loss': 0.12025038,
#  'Loss/total_loss': 0.2353469,
#  'learning_rate': 0.07352352}
# I1205 04:19:21.299295 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07960798,
#  'Loss/localization_loss': 0.03548854,
#  'Loss/regularization_loss': 0.12025038,
#  'Loss/total_loss': 0.2353469,
#  'learning_rate': 0.07352352}
# INFO:tensorflow:Step 10100 per-step time 0.173s
# I1205 04:19:38.628415 138735047218304 model_lib_v2.py:705] Step 10100 per-step time 0.173s
# INFO:tensorflow:{'Loss/classification_loss': 0.07220489,
#  'Loss/localization_loss': 0.036098383,
#  'Loss/regularization_loss': 0.11983281,
#  'Loss/total_loss': 0.22813608,
#  'learning_rate': 0.07338293}
# I1205 04:19:38.628810 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07220489,
#  'Loss/localization_loss': 0.036098383,
#  'Loss/regularization_loss': 0.11983281,
#  'Loss/total_loss': 0.22813608,
#  'learning_rate': 0.07338293}
# INFO:tensorflow:Step 10200 per-step time 0.159s
# I1205 04:19:54.547688 138735047218304 model_lib_v2.py:705] Step 10200 per-step time 0.159s
# INFO:tensorflow:{'Loss/classification_loss': 0.09230053,
#  'Loss/localization_loss': 0.046962805,
#  'Loss/regularization_loss': 0.119359955,
#  'Loss/total_loss': 0.2586233,
#  'learning_rate': 0.073240966}
# I1205 04:19:54.548070 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.09230053,
#  'Loss/localization_loss': 0.046962805,
#  'Loss/regularization_loss': 0.119359955,
#  'Loss/total_loss': 0.2586233,
#  'learning_rate': 0.073240966}
# INFO:tensorflow:Step 10300 per-step time 0.159s
# I1205 04:20:10.407068 138735047218304 model_lib_v2.py:705] Step 10300 per-step time 0.159s
# INFO:tensorflow:{'Loss/classification_loss': 0.066957206,
#  'Loss/localization_loss': 0.039638802,
#  'Loss/regularization_loss': 0.11892494,
#  'Loss/total_loss': 0.22552094,
#  'learning_rate': 0.07309763}
# I1205 04:20:10.407386 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.066957206,
#  'Loss/localization_loss': 0.039638802,
#  'Loss/regularization_loss': 0.11892494,
#  'Loss/total_loss': 0.22552094,
#  'learning_rate': 0.07309763}
# INFO:tensorflow:Step 10400 per-step time 0.155s
# I1205 04:20:25.871942 138735047218304 model_lib_v2.py:705] Step 10400 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.05584323,
#  'Loss/localization_loss': 0.03048339,
#  'Loss/regularization_loss': 0.11845441,
#  'Loss/total_loss': 0.20478103,
#  'learning_rate': 0.07295293}
# I1205 04:20:25.872278 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05584323,
#  'Loss/localization_loss': 0.03048339,
#  'Loss/regularization_loss': 0.11845441,
#  'Loss/total_loss': 0.20478103,
#  'learning_rate': 0.07295293}
# INFO:tensorflow:Step 10500 per-step time 0.156s
# I1205 04:20:41.481429 138735047218304 model_lib_v2.py:705] Step 10500 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.057756588,
#  'Loss/localization_loss': 0.026628025,
#  'Loss/regularization_loss': 0.11800116,
#  'Loss/total_loss': 0.20238578,
#  'learning_rate': 0.07280689}
# I1205 04:20:41.481842 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.057756588,
#  'Loss/localization_loss': 0.026628025,
#  'Loss/regularization_loss': 0.11800116,
#  'Loss/total_loss': 0.20238578,
#  'learning_rate': 0.07280689}
# INFO:tensorflow:Step 10600 per-step time 0.156s
# I1205 04:20:57.107440 138735047218304 model_lib_v2.py:705] Step 10600 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.08858304,
#  'Loss/localization_loss': 0.048542492,
#  'Loss/regularization_loss': 0.11756135,
#  'Loss/total_loss': 0.25468686,
#  'learning_rate': 0.07265949}
# I1205 04:20:57.107743 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08858304,
#  'Loss/localization_loss': 0.048542492,
#  'Loss/regularization_loss': 0.11756135,
#  'Loss/total_loss': 0.25468686,
#  'learning_rate': 0.07265949}
# INFO:tensorflow:Step 10700 per-step time 0.155s
# I1205 04:21:12.576960 138735047218304 model_lib_v2.py:705] Step 10700 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.08723944,
#  'Loss/localization_loss': 0.046006482,
#  'Loss/regularization_loss': 0.117158584,
#  'Loss/total_loss': 0.2504045,
#  'learning_rate': 0.07251076}
# I1205 04:21:12.577291 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08723944,
#  'Loss/localization_loss': 0.046006482,
#  'Loss/regularization_loss': 0.117158584,
#  'Loss/total_loss': 0.2504045,
#  'learning_rate': 0.07251076}
# INFO:tensorflow:Step 10800 per-step time 0.155s
# I1205 04:21:28.089973 138735047218304 model_lib_v2.py:705] Step 10800 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.06424922,
#  'Loss/localization_loss': 0.03325143,
#  'Loss/regularization_loss': 0.11677412,
#  'Loss/total_loss': 0.21427476,
#  'learning_rate': 0.07236068}
# I1205 04:21:28.090327 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06424922,
#  'Loss/localization_loss': 0.03325143,
#  'Loss/regularization_loss': 0.11677412,
#  'Loss/total_loss': 0.21427476,
#  'learning_rate': 0.07236068}
# INFO:tensorflow:Step 10900 per-step time 0.156s
# I1205 04:21:43.653007 138735047218304 model_lib_v2.py:705] Step 10900 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.08524695,
#  'Loss/localization_loss': 0.04810411,
#  'Loss/regularization_loss': 0.116341956,
#  'Loss/total_loss': 0.249693,
#  'learning_rate': 0.07220927}
# I1205 04:21:43.653338 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08524695,
#  'Loss/localization_loss': 0.04810411,
#  'Loss/regularization_loss': 0.116341956,
#  'Loss/total_loss': 0.249693,
#  'learning_rate': 0.07220927}
# INFO:tensorflow:Step 11000 per-step time 0.156s
# I1205 04:21:59.209727 138735047218304 model_lib_v2.py:705] Step 11000 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.07044902,
#  'Loss/localization_loss': 0.034199998,
#  'Loss/regularization_loss': 0.11596819,
#  'Loss/total_loss': 0.2206172,
#  'learning_rate': 0.07205655}
# I1205 04:21:59.210033 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07044902,
#  'Loss/localization_loss': 0.034199998,
#  'Loss/regularization_loss': 0.11596819,
#  'Loss/total_loss': 0.2206172,
#  'learning_rate': 0.07205655}
# INFO:tensorflow:Step 11100 per-step time 0.168s
# I1205 04:22:15.982495 138735047218304 model_lib_v2.py:705] Step 11100 per-step time 0.168s
# INFO:tensorflow:{'Loss/classification_loss': 0.058248784,
#  'Loss/localization_loss': 0.024927426,
#  'Loss/regularization_loss': 0.11559184,
#  'Loss/total_loss': 0.19876805,
#  'learning_rate': 0.07190249}
# I1205 04:22:15.982820 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.058248784,
#  'Loss/localization_loss': 0.024927426,
#  'Loss/regularization_loss': 0.11559184,
#  'Loss/total_loss': 0.19876805,
#  'learning_rate': 0.07190249}
# INFO:tensorflow:Step 11200 per-step time 0.155s
# I1205 04:22:31.510499 138735047218304 model_lib_v2.py:705] Step 11200 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.08261971,
#  'Loss/localization_loss': 0.038421236,
#  'Loss/regularization_loss': 0.11526513,
#  'Loss/total_loss': 0.23630607,
#  'learning_rate': 0.07174714}
# I1205 04:22:31.510799 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08261971,
#  'Loss/localization_loss': 0.038421236,
#  'Loss/regularization_loss': 0.11526513,
#  'Loss/total_loss': 0.23630607,
#  'learning_rate': 0.07174714}
# INFO:tensorflow:Step 11300 per-step time 0.157s
# I1205 04:22:47.175044 138735047218304 model_lib_v2.py:705] Step 11300 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.06585891,
#  'Loss/localization_loss': 0.023429291,
#  'Loss/regularization_loss': 0.11487627,
#  'Loss/total_loss': 0.20416448,
#  'learning_rate': 0.071590476}
# I1205 04:22:47.175356 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06585891,
#  'Loss/localization_loss': 0.023429291,
#  'Loss/regularization_loss': 0.11487627,
#  'Loss/total_loss': 0.20416448,
#  'learning_rate': 0.071590476}
# INFO:tensorflow:Step 11400 per-step time 0.155s
# I1205 04:23:02.644543 138735047218304 model_lib_v2.py:705] Step 11400 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.09476115,
#  'Loss/localization_loss': 0.03807671,
#  'Loss/regularization_loss': 0.114541784,
#  'Loss/total_loss': 0.24737965,
#  'learning_rate': 0.071432516}
# I1205 04:23:02.644848 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.09476115,
#  'Loss/localization_loss': 0.03807671,
#  'Loss/regularization_loss': 0.114541784,
#  'Loss/total_loss': 0.24737965,
#  'learning_rate': 0.071432516}
# INFO:tensorflow:Step 11500 per-step time 0.156s
# I1205 04:23:18.278799 138735047218304 model_lib_v2.py:705] Step 11500 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.07112752,
#  'Loss/localization_loss': 0.038789958,
#  'Loss/regularization_loss': 0.114269935,
#  'Loss/total_loss': 0.2241874,
#  'learning_rate': 0.07127326}
# I1205 04:23:18.279127 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07112752,
#  'Loss/localization_loss': 0.038789958,
#  'Loss/regularization_loss': 0.114269935,
#  'Loss/total_loss': 0.2241874,
#  'learning_rate': 0.07127326}
# INFO:tensorflow:Step 11600 per-step time 0.155s
# I1205 04:23:33.822036 138735047218304 model_lib_v2.py:705] Step 11600 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.07012424,
#  'Loss/localization_loss': 0.035085414,
#  'Loss/regularization_loss': 0.11394682,
#  'Loss/total_loss': 0.21915647,
#  'learning_rate': 0.071112715}
# I1205 04:23:33.822373 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07012424,
#  'Loss/localization_loss': 0.035085414,
#  'Loss/regularization_loss': 0.11394682,
#  'Loss/total_loss': 0.21915647,
#  'learning_rate': 0.071112715}
# INFO:tensorflow:Step 11700 per-step time 0.158s
# I1205 04:23:49.661883 138735047218304 model_lib_v2.py:705] Step 11700 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.09643595,
#  'Loss/localization_loss': 0.045080837,
#  'Loss/regularization_loss': 0.11361442,
#  'Loss/total_loss': 0.2551312,
#  'learning_rate': 0.070950896}
# I1205 04:23:49.662277 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.09643595,
#  'Loss/localization_loss': 0.045080837,
#  'Loss/regularization_loss': 0.11361442,
#  'Loss/total_loss': 0.2551312,
#  'learning_rate': 0.070950896}
# INFO:tensorflow:Step 11800 per-step time 0.156s
# I1205 04:24:05.239665 138735047218304 model_lib_v2.py:705] Step 11800 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.07449074,
#  'Loss/localization_loss': 0.052408095,
#  'Loss/regularization_loss': 0.11325926,
#  'Loss/total_loss': 0.24015811,
#  'learning_rate': 0.07078781}
# I1205 04:24:05.240017 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07449074,
#  'Loss/localization_loss': 0.052408095,
#  'Loss/regularization_loss': 0.11325926,
#  'Loss/total_loss': 0.24015811,
#  'learning_rate': 0.07078781}
# INFO:tensorflow:Step 11900 per-step time 0.158s
# I1205 04:24:21.023855 138735047218304 model_lib_v2.py:705] Step 11900 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.07206552,
#  'Loss/localization_loss': 0.024717318,
#  'Loss/regularization_loss': 0.11287512,
#  'Loss/total_loss': 0.20965795,
#  'learning_rate': 0.07062345}
# I1205 04:24:21.024268 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07206552,
#  'Loss/localization_loss': 0.024717318,
#  'Loss/regularization_loss': 0.11287512,
#  'Loss/total_loss': 0.20965795,
#  'learning_rate': 0.07062345}
# INFO:tensorflow:Step 12000 per-step time 0.156s
# I1205 04:24:36.636921 138735047218304 model_lib_v2.py:705] Step 12000 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.08561491,
#  'Loss/localization_loss': 0.06089187,
#  'Loss/regularization_loss': 0.11346255,
#  'Loss/total_loss': 0.25996935,
#  'learning_rate': 0.07045784}
# I1205 04:24:36.637295 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08561491,
#  'Loss/localization_loss': 0.06089187,
#  'Loss/regularization_loss': 0.11346255,
#  'Loss/total_loss': 0.25996935,
#  'learning_rate': 0.07045784}
# INFO:tensorflow:Step 12100 per-step time 0.173s
# I1205 04:24:53.987066 138735047218304 model_lib_v2.py:705] Step 12100 per-step time 0.173s
# INFO:tensorflow:{'Loss/classification_loss': 0.07227259,
#  'Loss/localization_loss': 0.07121878,
#  'Loss/regularization_loss': 0.11317265,
#  'Loss/total_loss': 0.25666404,
#  'learning_rate': 0.07029097}
# I1205 04:24:53.987471 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07227259,
#  'Loss/localization_loss': 0.07121878,
#  'Loss/regularization_loss': 0.11317265,
#  'Loss/total_loss': 0.25666404,
#  'learning_rate': 0.07029097}
# INFO:tensorflow:Step 12200 per-step time 0.158s
# I1205 04:25:09.758968 138735047218304 model_lib_v2.py:705] Step 12200 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.06213917,
#  'Loss/localization_loss': 0.02299353,
#  'Loss/regularization_loss': 0.112772845,
#  'Loss/total_loss': 0.19790554,
#  'learning_rate': 0.07012285}
# I1205 04:25:09.759317 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06213917,
#  'Loss/localization_loss': 0.02299353,
#  'Loss/regularization_loss': 0.112772845,
#  'Loss/total_loss': 0.19790554,
#  'learning_rate': 0.07012285}
# INFO:tensorflow:Step 12300 per-step time 0.155s
# I1205 04:25:25.302047 138735047218304 model_lib_v2.py:705] Step 12300 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.06188705,
#  'Loss/localization_loss': 0.037176587,
#  'Loss/regularization_loss': 0.112547465,
#  'Loss/total_loss': 0.21161109,
#  'learning_rate': 0.06995351}
# I1205 04:25:25.302466 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06188705,
#  'Loss/localization_loss': 0.037176587,
#  'Loss/regularization_loss': 0.112547465,
#  'Loss/total_loss': 0.21161109,
#  'learning_rate': 0.06995351}
# INFO:tensorflow:Step 12400 per-step time 0.155s
# I1205 04:25:40.803526 138735047218304 model_lib_v2.py:705] Step 12400 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.08627431,
#  'Loss/localization_loss': 0.046306852,
#  'Loss/regularization_loss': 0.112225614,
#  'Loss/total_loss': 0.24480677,
#  'learning_rate': 0.06978292}
# I1205 04:25:40.803847 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08627431,
#  'Loss/localization_loss': 0.046306852,
#  'Loss/regularization_loss': 0.112225614,
#  'Loss/total_loss': 0.24480677,
#  'learning_rate': 0.06978292}
# INFO:tensorflow:Step 12500 per-step time 0.154s
# I1205 04:25:56.251344 138735047218304 model_lib_v2.py:705] Step 12500 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.094497755,
#  'Loss/localization_loss': 0.041449096,
#  'Loss/regularization_loss': 0.11216974,
#  'Loss/total_loss': 0.2481166,
#  'learning_rate': 0.06961112}
# I1205 04:25:56.251670 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.094497755,
#  'Loss/localization_loss': 0.041449096,
#  'Loss/regularization_loss': 0.11216974,
#  'Loss/total_loss': 0.2481166,
#  'learning_rate': 0.06961112}
# INFO:tensorflow:Step 12600 per-step time 0.156s
# I1205 04:26:11.811877 138735047218304 model_lib_v2.py:705] Step 12600 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.09730752,
#  'Loss/localization_loss': 0.06052996,
#  'Loss/regularization_loss': 0.111851975,
#  'Loss/total_loss': 0.26968944,
#  'learning_rate': 0.06943809}
# I1205 04:26:11.812197 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.09730752,
#  'Loss/localization_loss': 0.06052996,
#  'Loss/regularization_loss': 0.111851975,
#  'Loss/total_loss': 0.26968944,
#  'learning_rate': 0.06943809}
# INFO:tensorflow:Step 12700 per-step time 0.156s
# I1205 04:26:27.372721 138735047218304 model_lib_v2.py:705] Step 12700 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.07228793,
#  'Loss/localization_loss': 0.03677929,
#  'Loss/regularization_loss': 0.11155542,
#  'Loss/total_loss': 0.22062263,
#  'learning_rate': 0.06926386}
# I1205 04:26:27.373082 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07228793,
#  'Loss/localization_loss': 0.03677929,
#  'Loss/regularization_loss': 0.11155542,
#  'Loss/total_loss': 0.22062263,
#  'learning_rate': 0.06926386}
# INFO:tensorflow:Step 12800 per-step time 0.158s
# I1205 04:26:43.130046 138735047218304 model_lib_v2.py:705] Step 12800 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.07231126,
#  'Loss/localization_loss': 0.028604144,
#  'Loss/regularization_loss': 0.11127568,
#  'Loss/total_loss': 0.21219108,
#  'learning_rate': 0.06908842}
# I1205 04:26:43.130364 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07231126,
#  'Loss/localization_loss': 0.028604144,
#  'Loss/regularization_loss': 0.11127568,
#  'Loss/total_loss': 0.21219108,
#  'learning_rate': 0.06908842}
# INFO:tensorflow:Step 12900 per-step time 0.154s
# I1205 04:26:58.568897 138735047218304 model_lib_v2.py:705] Step 12900 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.071448974,
#  'Loss/localization_loss': 0.024803994,
#  'Loss/regularization_loss': 0.11091887,
#  'Loss/total_loss': 0.20717184,
#  'learning_rate': 0.06891179}
# I1205 04:26:58.569201 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.071448974,
#  'Loss/localization_loss': 0.024803994,
#  'Loss/regularization_loss': 0.11091887,
#  'Loss/total_loss': 0.20717184,
#  'learning_rate': 0.06891179}
# INFO:tensorflow:Step 13000 per-step time 0.154s
# I1205 04:27:14.004852 138735047218304 model_lib_v2.py:705] Step 13000 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.05347018,
#  'Loss/localization_loss': 0.030364743,
#  'Loss/regularization_loss': 0.11052043,
#  'Loss/total_loss': 0.19435535,
#  'learning_rate': 0.068733975}
# I1205 04:27:14.005178 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05347018,
#  'Loss/localization_loss': 0.030364743,
#  'Loss/regularization_loss': 0.11052043,
#  'Loss/total_loss': 0.19435535,
#  'learning_rate': 0.068733975}
# INFO:tensorflow:Step 13100 per-step time 0.165s
# I1205 04:27:30.541447 138735047218304 model_lib_v2.py:705] Step 13100 per-step time 0.165s
# INFO:tensorflow:{'Loss/classification_loss': 0.06790892,
#  'Loss/localization_loss': 0.03617188,
#  'Loss/regularization_loss': 0.110136434,
#  'Loss/total_loss': 0.21421723,
#  'learning_rate': 0.068554975}
# I1205 04:27:30.541784 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06790892,
#  'Loss/localization_loss': 0.03617188,
#  'Loss/regularization_loss': 0.110136434,
#  'Loss/total_loss': 0.21421723,
#  'learning_rate': 0.068554975}
# INFO:tensorflow:Step 13200 per-step time 0.156s
# I1205 04:27:46.091846 138735047218304 model_lib_v2.py:705] Step 13200 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.06554308,
#  'Loss/localization_loss': 0.01999353,
#  'Loss/regularization_loss': 0.10976293,
#  'Loss/total_loss': 0.19529954,
#  'learning_rate': 0.0683748}
# I1205 04:27:46.092150 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06554308,
#  'Loss/localization_loss': 0.01999353,
#  'Loss/regularization_loss': 0.10976293,
#  'Loss/total_loss': 0.19529954,
#  'learning_rate': 0.0683748}
# INFO:tensorflow:Step 13300 per-step time 0.156s
# I1205 04:28:01.711449 138735047218304 model_lib_v2.py:705] Step 13300 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.051090352,
#  'Loss/localization_loss': 0.019961258,
#  'Loss/regularization_loss': 0.109573334,
#  'Loss/total_loss': 0.18062495,
#  'learning_rate': 0.06819345}
# I1205 04:28:01.711769 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.051090352,
#  'Loss/localization_loss': 0.019961258,
#  'Loss/regularization_loss': 0.109573334,
#  'Loss/total_loss': 0.18062495,
#  'learning_rate': 0.06819345}
# INFO:tensorflow:Step 13400 per-step time 0.154s
# I1205 04:28:17.134167 138735047218304 model_lib_v2.py:705] Step 13400 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.07054786,
#  'Loss/localization_loss': 0.025029445,
#  'Loss/regularization_loss': 0.1092329,
#  'Loss/total_loss': 0.2048102,
#  'learning_rate': 0.06801095}
# I1205 04:28:17.134491 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07054786,
#  'Loss/localization_loss': 0.025029445,
#  'Loss/regularization_loss': 0.1092329,
#  'Loss/total_loss': 0.2048102,
#  'learning_rate': 0.06801095}
# INFO:tensorflow:Step 13500 per-step time 0.155s
# I1205 04:28:32.604580 138735047218304 model_lib_v2.py:705] Step 13500 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.065410145,
#  'Loss/localization_loss': 0.030900817,
#  'Loss/regularization_loss': 0.10884149,
#  'Loss/total_loss': 0.20515245,
#  'learning_rate': 0.0678273}
# I1205 04:28:32.604947 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.065410145,
#  'Loss/localization_loss': 0.030900817,
#  'Loss/regularization_loss': 0.10884149,
#  'Loss/total_loss': 0.20515245,
#  'learning_rate': 0.0678273}
# INFO:tensorflow:Step 13600 per-step time 0.156s
# I1205 04:28:48.236891 138735047218304 model_lib_v2.py:705] Step 13600 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.0625015,
#  'Loss/localization_loss': 0.021124361,
#  'Loss/regularization_loss': 0.10846812,
#  'Loss/total_loss': 0.19209398,
#  'learning_rate': 0.0676425}
# I1205 04:28:48.237261 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.0625015,
#  'Loss/localization_loss': 0.021124361,
#  'Loss/regularization_loss': 0.10846812,
#  'Loss/total_loss': 0.19209398,
#  'learning_rate': 0.0676425}
# INFO:tensorflow:Step 13700 per-step time 0.156s
# I1205 04:29:03.882975 138735047218304 model_lib_v2.py:705] Step 13700 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.06852751,
#  'Loss/localization_loss': 0.02230436,
#  'Loss/regularization_loss': 0.10810025,
#  'Loss/total_loss': 0.19893213,
#  'learning_rate': 0.06745657}
# I1205 04:29:03.883336 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06852751,
#  'Loss/localization_loss': 0.02230436,
#  'Loss/regularization_loss': 0.10810025,
#  'Loss/total_loss': 0.19893213,
#  'learning_rate': 0.06745657}
# INFO:tensorflow:Step 13800 per-step time 0.156s
# I1205 04:29:19.448798 138735047218304 model_lib_v2.py:705] Step 13800 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.05482084,
#  'Loss/localization_loss': 0.032022446,
#  'Loss/regularization_loss': 0.10789462,
#  'Loss/total_loss': 0.19473791,
#  'learning_rate': 0.06726951}
# I1205 04:29:19.449167 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05482084,
#  'Loss/localization_loss': 0.032022446,
#  'Loss/regularization_loss': 0.10789462,
#  'Loss/total_loss': 0.19473791,
#  'learning_rate': 0.06726951}
# INFO:tensorflow:Step 13900 per-step time 0.156s
# I1205 04:29:35.011388 138735047218304 model_lib_v2.py:705] Step 13900 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.101106346,
#  'Loss/localization_loss': 0.025690546,
#  'Loss/regularization_loss': 0.10798265,
#  'Loss/total_loss': 0.23477954,
#  'learning_rate': 0.067081325}
# I1205 04:29:35.011764 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.101106346,
#  'Loss/localization_loss': 0.025690546,
#  'Loss/regularization_loss': 0.10798265,
#  'Loss/total_loss': 0.23477954,
#  'learning_rate': 0.067081325}
# INFO:tensorflow:Step 14000 per-step time 0.159s
# I1205 04:29:50.864521 138735047218304 model_lib_v2.py:705] Step 14000 per-step time 0.159s
# INFO:tensorflow:{'Loss/classification_loss': 0.05311961,
#  'Loss/localization_loss': 0.02770144,
#  'Loss/regularization_loss': 0.107659645,
#  'Loss/total_loss': 0.1884807,
#  'learning_rate': 0.06689203}
# I1205 04:29:50.864887 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05311961,
#  'Loss/localization_loss': 0.02770144,
#  'Loss/regularization_loss': 0.107659645,
#  'Loss/total_loss': 0.1884807,
#  'learning_rate': 0.06689203}
# INFO:tensorflow:Step 14100 per-step time 0.175s
# I1205 04:30:08.356343 138735047218304 model_lib_v2.py:705] Step 14100 per-step time 0.175s
# INFO:tensorflow:{'Loss/classification_loss': 0.07145122,
#  'Loss/localization_loss': 0.033796713,
#  'Loss/regularization_loss': 0.10728152,
#  'Loss/total_loss': 0.21252945,
#  'learning_rate': 0.06670163}
# I1205 04:30:08.356663 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07145122,
#  'Loss/localization_loss': 0.033796713,
#  'Loss/regularization_loss': 0.10728152,
#  'Loss/total_loss': 0.21252945,
#  'learning_rate': 0.06670163}
# INFO:tensorflow:Step 14200 per-step time 0.156s
# I1205 04:30:23.913987 138735047218304 model_lib_v2.py:705] Step 14200 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.05082995,
#  'Loss/localization_loss': 0.031640828,
#  'Loss/regularization_loss': 0.10696759,
#  'Loss/total_loss': 0.18943837,
#  'learning_rate': 0.06651013}
# I1205 04:30:23.914304 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05082995,
#  'Loss/localization_loss': 0.031640828,
#  'Loss/regularization_loss': 0.10696759,
#  'Loss/total_loss': 0.18943837,
#  'learning_rate': 0.06651013}
# INFO:tensorflow:Step 14300 per-step time 0.155s
# I1205 04:30:39.440680 138735047218304 model_lib_v2.py:705] Step 14300 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.07371871,
#  'Loss/localization_loss': 0.025122223,
#  'Loss/regularization_loss': 0.10663952,
#  'Loss/total_loss': 0.20548046,
#  'learning_rate': 0.06631755}
# I1205 04:30:39.440968 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07371871,
#  'Loss/localization_loss': 0.025122223,
#  'Loss/regularization_loss': 0.10663952,
#  'Loss/total_loss': 0.20548046,
#  'learning_rate': 0.06631755}
# INFO:tensorflow:Step 14400 per-step time 0.154s
# I1205 04:30:54.843951 138735047218304 model_lib_v2.py:705] Step 14400 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.08143488,
#  'Loss/localization_loss': 0.045670155,
#  'Loss/regularization_loss': 0.106273875,
#  'Loss/total_loss': 0.23337892,
#  'learning_rate': 0.06612387}
# I1205 04:30:54.844249 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08143488,
#  'Loss/localization_loss': 0.045670155,
#  'Loss/regularization_loss': 0.106273875,
#  'Loss/total_loss': 0.23337892,
#  'learning_rate': 0.06612387}
# INFO:tensorflow:Step 14500 per-step time 0.155s
# I1205 04:31:10.372766 138735047218304 model_lib_v2.py:705] Step 14500 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.06468183,
#  'Loss/localization_loss': 0.028964035,
#  'Loss/regularization_loss': 0.105978884,
#  'Loss/total_loss': 0.19962475,
#  'learning_rate': 0.06592914}
# I1205 04:31:10.373149 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06468183,
#  'Loss/localization_loss': 0.028964035,
#  'Loss/regularization_loss': 0.105978884,
#  'Loss/total_loss': 0.19962475,
#  'learning_rate': 0.06592914}
# INFO:tensorflow:Step 14600 per-step time 0.155s
# I1205 04:31:25.867455 138735047218304 model_lib_v2.py:705] Step 14600 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.05744548,
#  'Loss/localization_loss': 0.030126072,
#  'Loss/regularization_loss': 0.10568758,
#  'Loss/total_loss': 0.19325913,
#  'learning_rate': 0.06573333}
# I1205 04:31:25.867810 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05744548,
#  'Loss/localization_loss': 0.030126072,
#  'Loss/regularization_loss': 0.10568758,
#  'Loss/total_loss': 0.19325913,
#  'learning_rate': 0.06573333}
# INFO:tensorflow:Step 14700 per-step time 0.156s
# I1205 04:31:41.479077 138735047218304 model_lib_v2.py:705] Step 14700 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.06971821,
#  'Loss/localization_loss': 0.028356876,
#  'Loss/regularization_loss': 0.10535283,
#  'Loss/total_loss': 0.20342791,
#  'learning_rate': 0.06553646}
# I1205 04:31:41.479400 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06971821,
#  'Loss/localization_loss': 0.028356876,
#  'Loss/regularization_loss': 0.10535283,
#  'Loss/total_loss': 0.20342791,
#  'learning_rate': 0.06553646}
# INFO:tensorflow:Step 14800 per-step time 0.155s
# I1205 04:31:56.948937 138735047218304 model_lib_v2.py:705] Step 14800 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.0585254,
#  'Loss/localization_loss': 0.02449305,
#  'Loss/regularization_loss': 0.1051519,
#  'Loss/total_loss': 0.18817034,
#  'learning_rate': 0.065338545}
# I1205 04:31:56.949271 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.0585254,
#  'Loss/localization_loss': 0.02449305,
#  'Loss/regularization_loss': 0.1051519,
#  'Loss/total_loss': 0.18817034,
#  'learning_rate': 0.065338545}
# INFO:tensorflow:Step 14900 per-step time 0.156s
# I1205 04:32:12.520351 138735047218304 model_lib_v2.py:705] Step 14900 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.061252024,
#  'Loss/localization_loss': 0.030765375,
#  'Loss/regularization_loss': 0.104817055,
#  'Loss/total_loss': 0.19683444,
#  'learning_rate': 0.06513958}
# I1205 04:32:12.520669 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.061252024,
#  'Loss/localization_loss': 0.030765375,
#  'Loss/regularization_loss': 0.104817055,
#  'Loss/total_loss': 0.19683444,
#  'learning_rate': 0.06513958}
# INFO:tensorflow:Step 15000 per-step time 0.155s
# I1205 04:32:27.987105 138735047218304 model_lib_v2.py:705] Step 15000 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.077504225,
#  'Loss/localization_loss': 0.030737715,
#  'Loss/regularization_loss': 0.104468554,
#  'Loss/total_loss': 0.2127105,
#  'learning_rate': 0.064939596}
# I1205 04:32:27.987428 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.077504225,
#  'Loss/localization_loss': 0.030737715,
#  'Loss/regularization_loss': 0.104468554,
#  'Loss/total_loss': 0.2127105,
#  'learning_rate': 0.064939596}
# INFO:tensorflow:Step 15100 per-step time 0.172s
# I1205 04:32:45.141278 138735047218304 model_lib_v2.py:705] Step 15100 per-step time 0.172s
# INFO:tensorflow:{'Loss/classification_loss': 0.09819079,
#  'Loss/localization_loss': 0.050700862,
#  'Loss/regularization_loss': 0.104110666,
#  'Loss/total_loss': 0.25300232,
#  'learning_rate': 0.06473857}
# I1205 04:32:45.141629 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.09819079,
#  'Loss/localization_loss': 0.050700862,
#  'Loss/regularization_loss': 0.104110666,
#  'Loss/total_loss': 0.25300232,
#  'learning_rate': 0.06473857}
# INFO:tensorflow:Step 15200 per-step time 0.154s
# I1205 04:33:00.591487 138735047218304 model_lib_v2.py:705] Step 15200 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.07343775,
#  'Loss/localization_loss': 0.024544213,
#  'Loss/regularization_loss': 0.103750736,
#  'Loss/total_loss': 0.2017327,
#  'learning_rate': 0.06453654}
# I1205 04:33:00.591909 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.07343775,
#  'Loss/localization_loss': 0.024544213,
#  'Loss/regularization_loss': 0.103750736,
#  'Loss/total_loss': 0.2017327,
#  'learning_rate': 0.06453654}
# INFO:tensorflow:Step 15300 per-step time 0.158s
# I1205 04:33:16.411028 138735047218304 model_lib_v2.py:705] Step 15300 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.064174,
#  'Loss/localization_loss': 0.033517297,
#  'Loss/regularization_loss': 0.10348497,
#  'Loss/total_loss': 0.20117627,
#  'learning_rate': 0.06433349}
# I1205 04:33:16.411352 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.064174,
#  'Loss/localization_loss': 0.033517297,
#  'Loss/regularization_loss': 0.10348497,
#  'Loss/total_loss': 0.20117627,
#  'learning_rate': 0.06433349}
# INFO:tensorflow:Step 15400 per-step time 0.156s
# I1205 04:33:31.978116 138735047218304 model_lib_v2.py:705] Step 15400 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.047678046,
#  'Loss/localization_loss': 0.030037617,
#  'Loss/regularization_loss': 0.10316947,
#  'Loss/total_loss': 0.18088514,
#  'learning_rate': 0.06412946}
# I1205 04:33:31.978504 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.047678046,
#  'Loss/localization_loss': 0.030037617,
#  'Loss/regularization_loss': 0.10316947,
#  'Loss/total_loss': 0.18088514,
#  'learning_rate': 0.06412946}
# INFO:tensorflow:Step 15500 per-step time 0.156s
# I1205 04:33:47.606043 138735047218304 model_lib_v2.py:705] Step 15500 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.08643048,
#  'Loss/localization_loss': 0.053419054,
#  'Loss/regularization_loss': 0.10283045,
#  'Loss/total_loss': 0.24267998,
#  'learning_rate': 0.063924424}
# I1205 04:33:47.606441 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.08643048,
#  'Loss/localization_loss': 0.053419054,
#  'Loss/regularization_loss': 0.10283045,
#  'Loss/total_loss': 0.24267998,
#  'learning_rate': 0.063924424}
# INFO:tensorflow:Step 15600 per-step time 0.156s
# I1205 04:34:03.240321 138735047218304 model_lib_v2.py:705] Step 15600 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.11861622,
#  'Loss/localization_loss': 0.034887988,
#  'Loss/regularization_loss': 0.10246518,
#  'Loss/total_loss': 0.2559694,
#  'learning_rate': 0.0637184}
# I1205 04:34:03.240694 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.11861622,
#  'Loss/localization_loss': 0.034887988,
#  'Loss/regularization_loss': 0.10246518,
#  'Loss/total_loss': 0.2559694,
#  'learning_rate': 0.0637184}
# INFO:tensorflow:Step 15700 per-step time 0.156s
# I1205 04:34:18.802123 138735047218304 model_lib_v2.py:705] Step 15700 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.06811428,
#  'Loss/localization_loss': 0.034463167,
#  'Loss/regularization_loss': 0.102199435,
#  'Loss/total_loss': 0.20477688,
#  'learning_rate': 0.06351141}
# I1205 04:34:18.802534 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06811428,
#  'Loss/localization_loss': 0.034463167,
#  'Loss/regularization_loss': 0.102199435,
#  'Loss/total_loss': 0.20477688,
#  'learning_rate': 0.06351141}
# INFO:tensorflow:Step 15800 per-step time 0.156s
# I1205 04:34:34.368923 138735047218304 model_lib_v2.py:705] Step 15800 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.06333645,
#  'Loss/localization_loss': 0.04644292,
#  'Loss/regularization_loss': 0.10186844,
#  'Loss/total_loss': 0.21164781,
#  'learning_rate': 0.06330345}
# I1205 04:34:34.369284 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.06333645,
#  'Loss/localization_loss': 0.04644292,
#  'Loss/regularization_loss': 0.10186844,
#  'Loss/total_loss': 0.21164781,
#  'learning_rate': 0.06330345}
# INFO:tensorflow:Step 15900 per-step time 0.158s
# I1205 04:34:50.218179 138735047218304 model_lib_v2.py:705] Step 15900 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.05218054,
#  'Loss/localization_loss': 0.01960724,
#  'Loss/regularization_loss': 0.101662934,
#  'Loss/total_loss': 0.17345071,
#  'learning_rate': 0.06309453}
# I1205 04:34:50.218582 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05218054,
#  'Loss/localization_loss': 0.01960724,
#  'Loss/regularization_loss': 0.101662934,
#  'Loss/total_loss': 0.17345071,
#  'learning_rate': 0.06309453}
# INFO:tensorflow:Step 16000 per-step time 0.165s
# I1205 04:35:06.764504 138735047218304 model_lib_v2.py:705] Step 16000 per-step time 0.165s
# INFO:tensorflow:{'Loss/classification_loss': 0.0617066,
#  'Loss/localization_loss': 0.028832851,
#  'Loss/regularization_loss': 0.10147663,
#  'Loss/total_loss': 0.19201608,
#  'learning_rate': 0.062884666}
# I1205 04:35:06.764919 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.0617066,
#  'Loss/localization_loss': 0.028832851,
#  'Loss/regularization_loss': 0.10147663,
#  'Loss/total_loss': 0.19201608,
#  'learning_rate': 0.062884666}
# INFO:tensorflow:Step 16100 per-step time 0.171s
# I1205 04:35:23.908694 138735047218304 model_lib_v2.py:705] Step 16100 per-step time 0.171s
# INFO:tensorflow:{'Loss/classification_loss': 0.0850203,
#  'Loss/localization_loss': 0.029624147,
#  'Loss/regularization_loss': 0.10116341,
#  'Loss/total_loss': 0.21580786,
#  'learning_rate': 0.06267385}
# I1205 04:35:23.909074 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.0850203,
#  'Loss/localization_loss': 0.029624147,
#  'Loss/regularization_loss': 0.10116341,
#  'Loss/total_loss': 0.21580786,
#  'learning_rate': 0.06267385}
# INFO:tensorflow:Step 16200 per-step time 0.155s
# I1205 04:35:39.449408 138735047218304 model_lib_v2.py:705] Step 16200 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.058220748,
#  'Loss/localization_loss': 0.02933465,
#  'Loss/regularization_loss': 0.100865826,
#  'Loss/total_loss': 0.18842122,
#  'learning_rate': 0.062462118}
# I1205 04:35:39.449748 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.058220748,
#  'Loss/localization_loss': 0.02933465,
#  'Loss/regularization_loss': 0.100865826,
#  'Loss/total_loss': 0.18842122,
#  'learning_rate': 0.062462118}
# INFO:tensorflow:Step 16300 per-step time 0.156s
# I1205 04:35:55.028212 138735047218304 model_lib_v2.py:705] Step 16300 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.064449154,
#  'Loss/localization_loss': 0.021032909,
#  'Loss/regularization_loss': 0.10071188,
#  'Loss/total_loss': 0.18619394,
#  'learning_rate': 0.06224946}
# I1205 04:35:55.028539 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.064449154,
#  'Loss/localization_loss': 0.021032909,
#  'Loss/regularization_loss': 0.10071188,
#  'Loss/total_loss': 0.18619394,
#  'learning_rate': 0.06224946}
# INFO:tensorflow:Step 16400 per-step time 0.155s
# I1205 04:36:10.520386 138735047218304 model_lib_v2.py:705] Step 16400 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.15084693,
#  'Loss/localization_loss': 0.061772645,
#  'Loss/regularization_loss': 0.10084464,
#  'Loss/total_loss': 0.31346422,
#  'learning_rate': 0.062035877}
# I1205 04:36:10.520691 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.15084693,
#  'Loss/localization_loss': 0.061772645,
#  'Loss/regularization_loss': 0.10084464,
#  'Loss/total_loss': 0.31346422,
#  'learning_rate': 0.062035877}
# INFO:tensorflow:Step 16500 per-step time 0.155s
# I1205 04:36:26.051829 138735047218304 model_lib_v2.py:705] Step 16500 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.055091023,
#  'Loss/localization_loss': 0.023904033,
#  'Loss/regularization_loss': 0.100615576,
#  'Loss/total_loss': 0.17961064,
#  'learning_rate': 0.061821394}
# I1205 04:36:26.052131 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.055091023,
#  'Loss/localization_loss': 0.023904033,
#  'Loss/regularization_loss': 0.100615576,
#  'Loss/total_loss': 0.17961064,
#  'learning_rate': 0.061821394}
# INFO:tensorflow:Step 16600 per-step time 0.157s
# I1205 04:36:41.801100 138735047218304 model_lib_v2.py:705] Step 16600 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.064696796,
#  'Loss/localization_loss': 0.023884445,
#  'Loss/regularization_loss': 0.10027463,
#  'Loss/total_loss': 0.18885587,
#  'learning_rate': 0.061606016}
# I1205 04:36:41.801434 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.064696796,
# ...
#  'Loss/total_loss': 0.091041155,
#  'learning_rate': 0.0005978322}
# INFO:tensorflow:Step 47400 per-step time 0.156s
# I1205 05:57:39.445980 138735047218304 model_lib_v2.py:705] Step 47400 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.02701293,
#  'Loss/localization_loss': 0.0050669922,
#  'Loss/regularization_loss': 0.06306517,
#  'Loss/total_loss': 0.09514509,
#  'learning_rate': 0.000554471}
# I1205 05:57:39.446367 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.02701293,
#  'Loss/localization_loss': 0.0050669922,
#  'Loss/regularization_loss': 0.06306517,
#  'Loss/total_loss': 0.09514509,
#  'learning_rate': 0.000554471}
# INFO:tensorflow:Step 47500 per-step time 0.156s
# I1205 05:57:55.027564 138735047218304 model_lib_v2.py:705] Step 47500 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.05861449,
#  'Loss/localization_loss': 0.008634857,
#  'Loss/regularization_loss': 0.06306248,
#  'Loss/total_loss': 0.13031182,
#  'learning_rate': 0.0005127263}
# I1205 05:57:55.027863 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.05861449,
#  'Loss/localization_loss': 0.008634857,
#  'Loss/regularization_loss': 0.06306248,
#  'Loss/total_loss': 0.13031182,
#  'learning_rate': 0.0005127263}
# INFO:tensorflow:Step 47600 per-step time 0.156s
# I1205 05:58:10.668527 138735047218304 model_lib_v2.py:705] Step 47600 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.019409824,
#  'Loss/localization_loss': 0.003003092,
#  'Loss/regularization_loss': 0.06306,
#  'Loss/total_loss': 0.08547292,
#  'learning_rate': 0.00047260997}
# I1205 05:58:10.668850 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.019409824,
#  'Loss/localization_loss': 0.003003092,
#  'Loss/regularization_loss': 0.06306,
#  'Loss/total_loss': 0.08547292,
#  'learning_rate': 0.00047260997}
# INFO:tensorflow:Step 47700 per-step time 0.162s
# I1205 05:58:26.856297 138735047218304 model_lib_v2.py:705] Step 47700 per-step time 0.162s
# INFO:tensorflow:{'Loss/classification_loss': 0.029500164,
#  'Loss/localization_loss': 0.0058442163,
#  'Loss/regularization_loss': 0.06305766,
#  'Loss/total_loss': 0.09840204,
#  'learning_rate': 0.0004341173}
# I1205 05:58:26.856661 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.029500164,
#  'Loss/localization_loss': 0.0058442163,
#  'Loss/regularization_loss': 0.06305766,
#  'Loss/total_loss': 0.09840204,
#  'learning_rate': 0.0004341173}
# INFO:tensorflow:Step 47800 per-step time 0.157s
# I1205 05:58:42.527000 138735047218304 model_lib_v2.py:705] Step 47800 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.029705267,
#  'Loss/localization_loss': 0.0043833647,
#  'Loss/regularization_loss': 0.063055545,
#  'Loss/total_loss': 0.09714418,
#  'learning_rate': 0.00039724825}
# I1205 05:58:42.527414 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.029705267,
#  'Loss/localization_loss': 0.0043833647,
#  'Loss/regularization_loss': 0.063055545,
#  'Loss/total_loss': 0.09714418,
#  'learning_rate': 0.00039724825}
# INFO:tensorflow:Step 47900 per-step time 0.156s
# I1205 05:58:58.069990 138735047218304 model_lib_v2.py:705] Step 47900 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.024830164,
#  'Loss/localization_loss': 0.0029822504,
#  'Loss/regularization_loss': 0.063053586,
#  'Loss/total_loss': 0.090866,
#  'learning_rate': 0.00036200762}
# I1205 05:58:58.070333 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.024830164,
#  'Loss/localization_loss': 0.0029822504,
#  'Loss/regularization_loss': 0.063053586,
#  'Loss/total_loss': 0.090866,
#  'learning_rate': 0.00036200762}
# INFO:tensorflow:Step 48000 per-step time 0.156s
# I1205 05:59:13.711666 138735047218304 model_lib_v2.py:705] Step 48000 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.03318242,
#  'Loss/localization_loss': 0.0052667963,
#  'Loss/regularization_loss': 0.06305182,
#  'Loss/total_loss': 0.10150103,
#  'learning_rate': 0.00032839776}
# I1205 05:59:13.711964 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.03318242,
#  'Loss/localization_loss': 0.0052667963,
#  'Loss/regularization_loss': 0.06305182,
#  'Loss/total_loss': 0.10150103,
#  'learning_rate': 0.00032839776}
# INFO:tensorflow:Step 48100 per-step time 0.166s
# I1205 05:59:30.345713 138735047218304 model_lib_v2.py:705] Step 48100 per-step time 0.166s
# INFO:tensorflow:{'Loss/classification_loss': 0.029933045,
#  'Loss/localization_loss': 0.0033866407,
#  'Loss/regularization_loss': 0.063050225,
#  'Loss/total_loss': 0.09636991,
#  'learning_rate': 0.00029641867}
# I1205 05:59:30.346056 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.029933045,
#  'Loss/localization_loss': 0.0033866407,
#  'Loss/regularization_loss': 0.063050225,
#  'Loss/total_loss': 0.09636991,
#  'learning_rate': 0.00029641867}
# INFO:tensorflow:Step 48200 per-step time 0.157s
# I1205 05:59:46.081676 138735047218304 model_lib_v2.py:705] Step 48200 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.024071414,
#  'Loss/localization_loss': 0.003753587,
#  'Loss/regularization_loss': 0.06304882,
#  'Loss/total_loss': 0.09087382,
#  'learning_rate': 0.00026607275}
# I1205 05:59:46.081999 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.024071414,
#  'Loss/localization_loss': 0.003753587,
#  'Loss/regularization_loss': 0.06304882,
#  'Loss/total_loss': 0.09087382,
#  'learning_rate': 0.00026607275}
# INFO:tensorflow:Step 48300 per-step time 0.157s
# I1205 06:00:01.777693 138735047218304 model_lib_v2.py:705] Step 48300 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.030237606,
#  'Loss/localization_loss': 0.005683484,
#  'Loss/regularization_loss': 0.06304754,
#  'Loss/total_loss': 0.09896863,
#  'learning_rate': 0.00023735761}
# I1205 06:00:01.778014 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.030237606,
#  'Loss/localization_loss': 0.005683484,
#  'Loss/regularization_loss': 0.06304754,
#  'Loss/total_loss': 0.09896863,
#  'learning_rate': 0.00023735761}
# INFO:tensorflow:Step 48400 per-step time 0.157s
# I1205 06:00:17.458423 138735047218304 model_lib_v2.py:705] Step 48400 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.019629385,
#  'Loss/localization_loss': 0.003454226,
#  'Loss/regularization_loss': 0.06304638,
#  'Loss/total_loss': 0.08612999,
#  'learning_rate': 0.00021027803}
# I1205 06:00:17.458775 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.019629385,
#  'Loss/localization_loss': 0.003454226,
#  'Loss/regularization_loss': 0.06304638,
#  'Loss/total_loss': 0.08612999,
#  'learning_rate': 0.00021027803}
# INFO:tensorflow:Step 48500 per-step time 0.154s
# I1205 06:00:32.854796 138735047218304 model_lib_v2.py:705] Step 48500 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.023802761,
#  'Loss/localization_loss': 0.0033044245,
#  'Loss/regularization_loss': 0.063045375,
#  'Loss/total_loss': 0.09015256,
#  'learning_rate': 0.000184834}
# I1205 06:00:32.855118 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.023802761,
#  'Loss/localization_loss': 0.0033044245,
#  'Loss/regularization_loss': 0.063045375,
#  'Loss/total_loss': 0.09015256,
#  'learning_rate': 0.000184834}
# INFO:tensorflow:Step 48600 per-step time 0.156s
# I1205 06:00:48.415912 138735047218304 model_lib_v2.py:705] Step 48600 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.03261667,
#  'Loss/localization_loss': 0.004251661,
#  'Loss/regularization_loss': 0.06304449,
#  'Loss/total_loss': 0.09991282,
#  'learning_rate': 0.0001610279}
# I1205 06:00:48.416229 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.03261667,
#  'Loss/localization_loss': 0.004251661,
#  'Loss/regularization_loss': 0.06304449,
#  'Loss/total_loss': 0.09991282,
#  'learning_rate': 0.0001610279}
# INFO:tensorflow:Step 48700 per-step time 0.156s
# I1205 06:01:04.041027 138735047218304 model_lib_v2.py:705] Step 48700 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.018119207,
#  'Loss/localization_loss': 0.0036353464,
#  'Loss/regularization_loss': 0.06304371,
#  'Loss/total_loss': 0.08479827,
#  'learning_rate': 0.00013885974}
# I1205 06:01:04.041347 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.018119207,
#  'Loss/localization_loss': 0.0036353464,
#  'Loss/regularization_loss': 0.06304371,
#  'Loss/total_loss': 0.08479827,
#  'learning_rate': 0.00013885974}
# INFO:tensorflow:Step 48800 per-step time 0.156s
# I1205 06:01:19.606897 138735047218304 model_lib_v2.py:705] Step 48800 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.026500892,
#  'Loss/localization_loss': 0.0037788798,
#  'Loss/regularization_loss': 0.06304305,
#  'Loss/total_loss': 0.09332282,
#  'learning_rate': 0.00011832714}
# I1205 06:01:19.607245 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.026500892,
#  'Loss/localization_loss': 0.0037788798,
#  'Loss/regularization_loss': 0.06304305,
#  'Loss/total_loss': 0.09332282,
#  'learning_rate': 0.00011832714}
# INFO:tensorflow:Step 48900 per-step time 0.156s
# I1205 06:01:35.211860 138735047218304 model_lib_v2.py:705] Step 48900 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.01926516,
#  'Loss/localization_loss': 0.008927869,
#  'Loss/regularization_loss': 0.06304249,
#  'Loss/total_loss': 0.09123552,
#  'learning_rate': 9.943485e-05}
# I1205 06:01:35.212167 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.01926516,
#  'Loss/localization_loss': 0.008927869,
#  'Loss/regularization_loss': 0.06304249,
#  'Loss/total_loss': 0.09123552,
#  'learning_rate': 9.943485e-05}
# INFO:tensorflow:Step 49000 per-step time 0.155s
# I1205 06:01:50.693541 138735047218304 model_lib_v2.py:705] Step 49000 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.032689333,
#  'Loss/localization_loss': 0.005021595,
#  'Loss/regularization_loss': 0.06304204,
#  'Loss/total_loss': 0.100752965,
#  'learning_rate': 8.218288e-05}
# I1205 06:01:50.693968 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.032689333,
#  'Loss/localization_loss': 0.005021595,
#  'Loss/regularization_loss': 0.06304204,
#  'Loss/total_loss': 0.100752965,
#  'learning_rate': 8.218288e-05}
# INFO:tensorflow:Step 49100 per-step time 0.172s
# I1205 06:02:07.856047 138735047218304 model_lib_v2.py:705] Step 49100 per-step time 0.172s
# INFO:tensorflow:{'Loss/classification_loss': 0.021398189,
#  'Loss/localization_loss': 0.00473146,
#  'Loss/regularization_loss': 0.06304164,
#  'Loss/total_loss': 0.08917129,
#  'learning_rate': 6.6573615e-05}
# I1205 06:02:07.856394 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.021398189,
#  'Loss/localization_loss': 0.00473146,
#  'Loss/regularization_loss': 0.06304164,
#  'Loss/total_loss': 0.08917129,
#  'learning_rate': 6.6573615e-05}
# INFO:tensorflow:Step 49200 per-step time 0.156s
# I1205 06:02:23.418398 138735047218304 model_lib_v2.py:705] Step 49200 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.025564874,
#  'Loss/localization_loss': 0.0043490916,
#  'Loss/regularization_loss': 0.063041344,
#  'Loss/total_loss': 0.092955306,
#  'learning_rate': 5.2604675e-05}
# I1205 06:02:23.418716 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.025564874,
#  'Loss/localization_loss': 0.0043490916,
#  'Loss/regularization_loss': 0.063041344,
#  'Loss/total_loss': 0.092955306,
#  'learning_rate': 5.2604675e-05}
# INFO:tensorflow:Step 49300 per-step time 0.156s
# I1205 06:02:39.000537 138735047218304 model_lib_v2.py:705] Step 49300 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.020810157,
#  'Loss/localization_loss': 0.005046391,
#  'Loss/regularization_loss': 0.0630411,
#  'Loss/total_loss': 0.088897645,
#  'learning_rate': 4.0278435e-05}
# I1205 06:02:39.000847 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.020810157,
#  'Loss/localization_loss': 0.005046391,
#  'Loss/regularization_loss': 0.0630411,
#  'Loss/total_loss': 0.088897645,
#  'learning_rate': 4.0278435e-05}
# INFO:tensorflow:Step 49400 per-step time 0.156s
# I1205 06:02:54.590492 138735047218304 model_lib_v2.py:705] Step 49400 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.02992856,
#  'Loss/localization_loss': 0.0057773506,
#  'Loss/regularization_loss': 0.06304093,
#  'Loss/total_loss': 0.098746836,
#  'learning_rate': 2.9592513e-05}
# I1205 06:02:54.590845 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.02992856,
#  'Loss/localization_loss': 0.0057773506,
#  'Loss/regularization_loss': 0.06304093,
#  'Loss/total_loss': 0.098746836,
#  'learning_rate': 2.9592513e-05}
# INFO:tensorflow:Step 49500 per-step time 0.157s
# I1205 06:03:10.279535 138735047218304 model_lib_v2.py:705] Step 49500 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.058137156,
#  'Loss/localization_loss': 0.030408492,
#  'Loss/regularization_loss': 0.063040785,
#  'Loss/total_loss': 0.15158644,
#  'learning_rate': 2.055168e-05}
# I1205 06:03:10.279947 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.058137156,
#  'Loss/localization_loss': 0.030408492,
#  'Loss/regularization_loss': 0.063040785,
#  'Loss/total_loss': 0.15158644,
#  'learning_rate': 2.055168e-05}
# INFO:tensorflow:Step 49600 per-step time 0.156s
# I1205 06:03:25.858991 138735047218304 model_lib_v2.py:705] Step 49600 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.022418784,
#  'Loss/localization_loss': 0.004354215,
#  'Loss/regularization_loss': 0.06304071,
#  'Loss/total_loss': 0.08981371,
#  'learning_rate': 1.3153553e-05}
# I1205 06:03:25.859383 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.022418784,
#  'Loss/localization_loss': 0.004354215,
#  'Loss/regularization_loss': 0.06304071,
#  'Loss/total_loss': 0.08981371,
#  'learning_rate': 1.3153553e-05}
# INFO:tensorflow:Step 49700 per-step time 0.157s
# I1205 06:03:41.588125 138735047218304 model_lib_v2.py:705] Step 49700 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.020657727,
#  'Loss/localization_loss': 0.0065082526,
#  'Loss/regularization_loss': 0.06304066,
#  'Loss/total_loss': 0.09020664,
#  'learning_rate': 7.398128e-06}
# I1205 06:03:41.593537 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.020657727,
#  'Loss/localization_loss': 0.0065082526,
#  'Loss/regularization_loss': 0.06304066,
#  'Loss/total_loss': 0.09020664,
#  'learning_rate': 7.398128e-06}
# INFO:tensorflow:Step 49800 per-step time 0.163s
# I1205 06:03:57.867573 138735047218304 model_lib_v2.py:705] Step 49800 per-step time 0.163s
# INFO:tensorflow:{'Loss/classification_loss': 0.025789227,
#  'Loss/localization_loss': 0.0040525533,
#  'Loss/regularization_loss': 0.06304063,
#  'Loss/total_loss': 0.09288241,
#  'learning_rate': 3.2877922e-06}
# I1205 06:03:57.867981 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.025789227,
#  'Loss/localization_loss': 0.0040525533,
#  'Loss/regularization_loss': 0.06304063,
#  'Loss/total_loss': 0.09288241,
#  'learning_rate': 3.2877922e-06}
# INFO:tensorflow:Step 49900 per-step time 0.157s
# I1205 06:04:13.511305 138735047218304 model_lib_v2.py:705] Step 49900 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.025938688,
#  'Loss/localization_loss': 0.00582966,
#  'Loss/regularization_loss': 0.06304063,
#  'Loss/total_loss': 0.09480898,
#  'learning_rate': 8.2254405e-07}
# I1205 06:04:13.511673 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.025938688,
#  'Loss/localization_loss': 0.00582966,
#  'Loss/regularization_loss': 0.06304063,
#  'Loss/total_loss': 0.09480898,
#  'learning_rate': 8.2254405e-07}
# INFO:tensorflow:Step 50000 per-step time 0.155s
# I1205 06:04:29.044072 138735047218304 model_lib_v2.py:705] Step 50000 per-step time 0.155s
# INFO:tensorflow:{'Loss/classification_loss': 0.029606445,
#  'Loss/localization_loss': 0.004266378,
#  'Loss/regularization_loss': 0.06304063,
#  'Loss/total_loss': 0.09691346,
#  'learning_rate': 0.0}
# I1205 06:04:29.044450 138735047218304 model_lib_v2.py:708] {'Loss/classification_loss': 0.029606445,
#  'Loss/localization_loss': 0.004266378,
#  'Loss/regularization_loss': 0.06304063,
#  'Loss/total_loss': 0.09691346,
#  'learning_rate': 0.0}

# %%
# !ls {model_dir}
# Out:
# ls: cannot access '{model_dir}': No such file or directory

# %% [markdown]
# ## Exporting Trained Inference Graphs
# Once your training job is complete, you need to extract the newly trained inference graph, which will be later used to perform the object detection. We do this again for TFLite. This can be done as follows:

# %%
# %cd /content/models/research

import re
import numpy as np

output_directory = './fine_tuned_model'
tflite_directory = './fine_tuned_model/tflite'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={pipeline_fname} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# !python /content/models/research/object_detection/export_tflite_ssd_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={pipeline_fname} \
    --output_directory={tflite_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# /content/models/research
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6ad86b8a6e37> in <cell line: 12>()
#      10 lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
#      11 steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
# ---> 12 last_model = lst[steps.argmax()].replace('.meta', '')
#      13
#      14 last_model_path = os.path.join(model_dir, last_model)
#
# ValueError: attempt to get argmax of an empty sequence

# %%
# !ls {output_directory}

# %% [markdown]
# ## Download the model `.pb` file

# %%
import os

pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
print(pb_fname)
assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)

# %%
# !ls -alh {pb_fname}

# %% [markdown]
# ### Option1 : upload the `.pb` file to your Google Drive
# Then download it from your Google Drive to local file system.
#
# During this step, you will be prompted to enter the token.

# %%
# # Install the PyDrive wrapper & import libraries.
# # This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# # Authenticate and create the PyDrive client.
# # This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

fname = os.path.basename(pb_fname)
# # Create & upload a text file.
uploaded = drive.CreateFile({'title': fname})
uploaded.SetContentFile(pb_fname)
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))

# %% [markdown]
# ### Option2 :  Download the `.pb` file directly to your local file system
# This method may not be stable when downloading large files like the model `.pb` file. Try **option 1** instead if not working.

# %%
from google.colab import files
files.download(pb_fname)

# %% [markdown]
# ### OPTIONAL: Download the `label_map.pbtxt` file

# %%
from google.colab import files
files.download(label_map_pbtxt_fname)

# %% [markdown]
# ### OPTIONAL: Download the modified pipline file
# If you plan to use OpenVINO toolkit to convert the `.pb` file to inference faster on Intel's hardware (CPU/GPU, Movidius, etc.)

# %%
files.download(pipeline_fname)

# %%
# !tar cfz fine_tuned_model.tar.gz fine_tuned_model
from google.colab import files
files.download('fine_tuned_model.tar.gz')

# %% [markdown]
# ## Run inference test
# Test with images in repository `tensorflow-object-detection/test` directory.
#
# **To test with your own images, you need to place your images inside the `test` directory in this Colab notebook!** More on this below.

# %%
# !cp -r /content/test/test/ /content/tensorflow-object-detection-faster-rcnn/

# %%
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
PATH_TO_TEST_IMAGES_DIR =  os.path.join(repo_dir_path, "test")

assert os.path.isfile(pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(PATH_TO_TEST_IMAGES_DIR, "*.*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
print(TEST_IMAGE_PATHS)

# %%
# !ls /content/tensorflow-object-detection-faster-rcnn/

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops


# This is needed to display the images.
# %matplotlib inline


from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict

# %%
# Output images not showing? Run this cell again, and try the cell above
# This is needed to display the images.
# %matplotlib inline

# %%
# Limited displayed images to 5 to reduce memory
count = 5
for i, image_path in enumerate(TEST_IMAGE_PATHS):
    if i > count:
        break
    image = Image.open(image_path)
    # the array based representation of the image will be used later in order to prepare the
    # result image with boxes and labels on it.
    image_np = load_image_into_numpy_array(image)
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np, detection_graph)
    # Visualization of the results of a detection.
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks'),
        use_normalized_coordinates=True,
        line_thickness=8)
    plt.figure(figsize=IMAGE_SIZE)
    plt.imshow(image_np)

# %% [markdown]
# # 3. Convert

# %% [markdown]
# With our model trained, it's time to convert our graph to .tflite!

# %%
# %ls /content/models/research/fine_tuned_model/tflite

# %%
# !tflite_convert \
  --input_shape=1,224,224,3 \
  --input_arrays=normalized_input_image_tensor \
  --output_arrays=MobilenetV1/Predictions/Softmax \
  --allow_custom_ops \
  --graph_def_file=/content/models/research/fine_tuned_model/tflite/tflite_graph.pb \
  --output_file="/content/models/research/fine_tuned_model/final_model.tflite"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import tensorflow as tf

# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter('/content/drive/MyDrive/final_model.tflite')
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test model on random input data.
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)

# %%
# Change the final TFLite destination here
# !cp /content/models/research/fine_tuned_model/final_model.tflite "/content/drive/My Drive/"

# %% [markdown]
# Your TFLite file is now in your Drive as "final_model.tflite", ready to use with your project on-device! For specific device tutorials, check out the official TensorFlow Lite [Android Demo](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/android), [iOS Demo](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/ios), or [Raspberry Pi Demo](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi). [link text](https://)

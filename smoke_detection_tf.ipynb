# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaAmirtharaj/cs249_final_project/blob/main/smoke_detection_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Import

# %% [markdown]
# ## Prepare Data
#
#
# To train a TensorFlow2 Object Detection Model, we need TFRecord and label_map files. Roboflow creates these files for us!
#
# Because we need one TFRecord file for our training data, and one TFRecord file for our test data, we'll split the dataset into "train" and "test".
#
# To create a dataset in Roboflow and generate TFRecords, follow [this step-by-step guide](https://blog.roboflow.ai/getting-started-with-roboflow/). On export, select "Tensorflow TFRecord" for the first link and "COCO JSON" as the second link below.

# %% [markdown]
# ![](https://i.imgur.com/ZwMdcbY.png)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kurHDAP4tAun3nyyYi4d")
project = rf.workspace("wildfire-xpwrf").project("wildfire-4tdl8")

# Specify the desired version of the dataset and the output directory
output_directory = "/content/Wildfire"
dataset = project.version(2).download("tfrecord", output_directory)
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.12-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 1.1 MB/s eta 0:00:00
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.9 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.9 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.16.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.8 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.45.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.4)
# Installing collected packages: python-magic, python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.12 supervision-0.16.0
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/Wildfire to tfrecord:: 100%|██████████| 33180/33180 [00:00<00:00, 64593.58it/s]
# Extracting Dataset Version Zip to /content/Wildfire in tfrecord:: 100%|██████████| 11/11 [00:00<00:00, 176.46it/s]

# %% [markdown]
# # 2. Train

# %% [markdown]
# _Note that this section is based on the [MobileNetSSDv2 Notebook](https://colab.research.google.com/drive/1wTMIrJhYsQdq_u7ROOkf0Lu_fsX5Mu8a). This is because TensorFlow Lite is independent of the model used, so we're picking a simple and lightweight solution._

# %% [markdown]
# ## Configs and Hyperparameters
#
# Support a variety of models, you can find more pretrained model from [Tensorflow detection model zoo: COCO-trained models](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md#coco-trained-models), as well as their pipline config files in [object_detection/samples/configs/](https://github.com/tensorflow/models/tree/master/research/object_detection/samples/configs).

# %%
# If you forked the repo, you can replace the link.
repo_url = 'https://github.com/roboflow-ai/tensorflow-object-detection-faster-rcnn'

# Number of training steps - 1000 will train very quickly, but more steps will increase accuracy.
num_steps = 1000  # 200000 to improve

# Number of evaluation steps.
num_eval_steps = 50

MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8',
        'pipeline_file': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config',
        'batch_size': 12
    },
    'faster_rcnn': { # Update to make compatible with TF2
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu',
        'pipeline_file': 'faster_rcnn_resnet50_v1_640x640_coco17_tpu-8.config',
        'batch_size': 12
    },
    'efficientdet': { # Update to make compatible with TF2
        'model_name': 'ssd_efficientdet_d4_1024x1024_coco17_tpu-32',
        'pipeline_file': 'ssd_efficientdet_d4_1024x1024_coco17_tpu-32.config',
        'batch_size': 8
    },
}


# Pick the model you want to use
# Select a model in `MODELS_CONFIG`.
selected_model = 'ssd_mobilenet_v2'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

# %% [markdown]
# ## Clone the `tensorflow-object-detection` repository or your fork.

# %%
import os

# %cd /content

repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))

# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# /content
# Cloning into 'tensorflow-object-detection-faster-rcnn'...
# remote: Enumerating objects: 885, done.
# remote: Total 885 (delta 0), reused 0 (delta 0), pack-reused 885
# Receiving objects: 100% (885/885), 24.83 MiB | 31.51 MiB/s, done.
# Resolving deltas: 100% (428/428), done.
# /content/tensorflow-object-detection-faster-rcnn
# Already up to date.

# %% [markdown]
# ## Install required packages

# %%
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git

# !pip install tf_slim

# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install tensorflow_io

# !pip install tf-models-official

# TF 2.13.0 is the only compatible version
# !pip uninstall -y tensorflow
# !pip install tensorflow==2.13.0

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf_slim) (1.4.0)
# E: Unable to locate package python-pil
# E: Unable to locate package python-lxml
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 54.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.34.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io) (0.34.0)
# Installing collected packages: tensorflow_io
# Successfully installed tensorflow_io-0.34.0
# Collecting tf-models-official
#   Downloading tf_models_official-2.15.0-py2.py3-none-any.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (3.0.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (9.4.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (2.84.0)
# Collecting immutabledict (from tf-models-official)
#   Downloading immutabledict-4.0.0-py3-none-any.whl (4.5 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.5.16)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.23.5)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.8.0.74)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.5.3)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (9.0.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (2.0.7)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (6.0.1)
# Collecting sacrebleu (from tf-models-official)
#   Downloading sacrebleu-2.3.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.11.4)
# Collecting sentencepiece (from tf-models-official)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.1 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.16.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.9.3)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (0.15.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official)
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 31.3 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.15.0 (from tf-models-official)
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 69.5 MB/s eta 0:00:00
# Collecting tensorflow~=2.15.0 (from tf-models-official)
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: tf-slim>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (4.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->tf-models-official) (2023.3.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.15.0->tf-models-official) (1.59.3)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow~=2.15.0->tf-models-official)
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 94.1 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow~=2.15.0->tf-models-official)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 50.7 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0 (from tensorflow~=2.15.0->tf-models-official)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.5 MB/s eta 0:00:00
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official) (0.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (2.4.7)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (4.9)
# Collecting portalocker (from sacrebleu->tf-models-official)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (0.9.0)
# Collecting colorama (from sacrebleu->tf-models-official)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (4.9.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official) (1.2.2)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (0.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (1.5.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (1.14.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.15.0->tf-models-official) (0.42.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (6.1.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (3.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official) (1.61.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official) (5.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official) (2.10)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (3.2.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (3.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle>=1.3.9->tf-models-official) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow~=2.15.0->tf-models-official) (3.2.2)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=9e7a1e1819321f809d7b431e962c82ffcdeffaf221f581e313c90eb78f2593fd
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: sentencepiece, tensorflow-model-optimization, tensorflow-estimator, portalocker, keras, immutabledict, colorama, sacrebleu, seqeval, tensorboard, tensorflow, tensorflow-text, tf-models-official
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# Successfully installed colorama-0.4.6 immutabledict-4.0.0 keras-2.15.0 portalocker-2.8.2 sacrebleu-2.3.3 sentencepiece-0.1.99 seqeval-1.2.2 tensorboard-2.15.1 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-model-optimization-0.7.5 tensorflow-text-2.15.0 tf-models-official-2.15.0
# Found existing installation: tensorflow 2.15.0
# Uninstalling tensorflow-2.15.0:
#   Successfully uninstalled tensorflow-2.15.0
# Collecting tensorflow==2.13.0
#   Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (23.5.26)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.13.0)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.59.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (3.9.0)
# Collecting keras<2.14,>=2.13.1 (from tensorflow==2.13.0)
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.16.0)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow==2.13.0)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 3.1 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow==2.13.0)
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13.0) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.13.0) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, gast, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.1
#     Uninstalling tensorboard-2.15.1:
#       Successfully uninstalled tensorboard-2.15.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.15.0 requires tensorflow<2.16,>=2.15.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.13.0 which is incompatible.
# tf-models-official 2.15.0 requires tensorflow~=2.15.0, but you have tensorflow 2.13.0 which is incompatible.
# Successfully installed gast-0.4.0 keras-2.13.1 tensorboard-2.13.0 tensorflow-2.13.0 tensorflow-estimator-2.13.0
# /content/models/research
# 2023-12-05 17:47:36.174920: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-05 17:47:37.174509: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Verify we are using Tensorflow 2.13.0
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.13.0

# %% [markdown]
# ## Prepare `tfrecord` files
#
# Roboflow automatically creates our TFRecord and label_map files that we need!
#
# **Generating your own TFRecords the only step you need to change for your own custom dataset.**
#
# Because we need one TFRecord file for our training data, and one TFRecord file for our test data, we'll create two separate datasets in Roboflow and generate one set of TFRecords for each.
#
# To create a dataset in Roboflow and generate TFRecords, follow [this step-by-step guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %%
# %cd /content/tensorflow-object-detection-faster-rcnn/data
# Out:
# /content/tensorflow-object-detection-faster-rcnn/data

# %%
# !cp -r /content/Wildfire/train/ /content/tensorflow-object-detection-faster-rcnn/data/
# !cp -r /content/Wildfire/test/ /content/tensorflow-object-detection-faster-rcnn/data/

# %%
# training set
# %ls train
# Out:
# fire_label_map.pbtxt  fire.tfrecord

# %%
# test set
# %ls test
# Out:
# fire_label_map.pbtxt  fire.tfrecord

# %%
test_record_fname = '/content/tensorflow-object-detection-faster-rcnn/data/test/fire.tfrecord'
train_record_fname = '/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord'
label_map_pbtxt_fname = '/content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt'

# %% [markdown]
# ## Download base model

# %%
# %cd /content/models/research

import os
import shutil
import glob
import urllib.request
import tarfile
MODEL_FILE = MODEL + '.tar.gz'
print(MODEL_FILE)
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/'
print(DOWNLOAD_BASE)
DEST_DIR = '/content/models/research/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)
# Out:
# /content/models/research
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# http://download.tensorflow.org/models/object_detection/tf2/20200711/

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/models/research/pretrained_model
# total 24K
# drwxr-x---  4 345018 89939 4.0K Jul 11  2020 .
# drwxr-xr-x 23 root   root  4.0K Dec  5 17:48 ..
# drwxr-x---  2 345018 89939 4.0K Jul 10  2020 checkpoint
# -rw-r-----  1 345018 89939 4.5K Jul 11  2020 pipeline.config
# drwxr-x---  3 345018 89939 4.0K Jul 10  2020 saved_model

# %%
import os

directory_path = '/content/models/research/pretrained_model/checkpoint'
os.listdir(directory_path)
# Out:
# ['checkpoint', 'ckpt-0.data-00000-of-00001', 'ckpt-0.index']

# %%
# Fix checkpoint naming scheme
import os
import glob

directory_path = '/content/models/research/pretrained_model/checkpoint'

# Loop through all files that start with 'model.ckpt-1.'
for filepath in glob.glob(os.path.join(directory_path, 'ckpt-0.*')):
    base_directory, filename = os.path.split(filepath)
    file_extension = filename.split('.', 2)[-1]

    # Construct the new filename
    new_filename = 'model.ckpt.' + file_extension

    # Construct the full path for the new file
    new_filepath = os.path.join(base_directory, new_filename)

    # Rename the file
    os.rename(filepath, new_filepath)
    print(f'Renamed {filepath} to {new_filepath}')
# Out:
# Renamed /content/models/research/pretrained_model/checkpoint/ckpt-0.data-00000-of-00001 to /content/models/research/pretrained_model/checkpoint/model.ckpt.data-00000-of-00001
# Renamed /content/models/research/pretrained_model/checkpoint/ckpt-0.index to /content/models/research/pretrained_model/checkpoint/model.ckpt.index

# %%
# Verify naming scheme of checkpoints
import os

directory_path = '/content/models/research/pretrained_model/checkpoint'
os.listdir(directory_path)
# Out:
# ['model.ckpt.data-00000-of-00001', 'checkpoint', 'model.ckpt.index']

# %% [markdown]
# ## Configuring a Training Pipeline

# %%
import os
pipeline_fname = os.path.join('/content/models/research/object_detection/configs/tf2/', pipeline_file)
print(pipeline_file)

assert os.path.isfile(pipeline_fname), '`{}` not exist'.format(pipeline_fname)
# Out:
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config

# %%
def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

# %%
import re

train_record = "/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord"
train_label_map = "/content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt"

test_record = "/content/tensorflow-object-detection-faster-rcnn/data/test/fire.tfrecord"
test_label_map = "/content/tensorflow-object-detection-faster-rcnn/data/test/fire_label_map.pbtxt"

checkpoint = "/content/models/research/pretrained_model/checkpoint/model.ckpt"

num_classes = get_num_classes(label_map_pbtxt_fname)

with open(pipeline_fname) as f:
    s = f.read()
with open(pipeline_fname, 'w') as f:

    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(checkpoint), s)

    s = re.sub('fine_tune_checkpoint_type: ".*?"',
               'fine_tune_checkpoint_type: "detection"', s)

    # label_map_path
    s = re.sub(r'(train_input_reader: {[\s\S]*?label_map_path: ")[^"]*(")',
               r'\1{}\2'.format(train_label_map), s)
    s = re.sub(r'(eval_input_reader: {[\s\S]*?label_map_path: ")[^"]*(")',
               r'\1{}\2'.format(test_label_map), s)

    # tfrecord paths
    s = re.sub(
        r'(train_input_reader: {\s+label_map_path: ".*?"\s+tf_record_input_reader {\s+input_path: ").*?(")',
        r'\1{}\2'.format(train_record), s)
    s = re.sub(
        r'(eval_input_reader: \{\s+label_map_path: ".*?"\s+shuffle: \w+\s+num_epochs: \d+\s+tf_record_input_reader \{\s+input_path: ").*?(")',
        r'\1{}\2'.format(test_record), s, flags=re.DOTALL)


    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)

    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    f.write(s)

# %%
# !cat {pipeline_fname}
# Out:
# # SSD with Mobilenet v2 FPN-lite (go/fpn-lite) feature extractor, shared box
# # predictor and focal loss (a mobile version of Retinanet).
# # Retinanet: see Lin et al, https://arxiv.org/abs/1708.02002
# # Trained on COCO, initialized from Imagenet classification checkpoint
# # Train on TPU-8
# #
# # Achieves 22.2 mAP on COCO17 Val
#
# model {
#   ssd {
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#     num_classes: 1
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     encode_background_as_zeros: true
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: [1.0, 2.0, 0.5]
#         scales_per_octave: 2
#       }
#     }
#     image_resizer {
#       fixed_shape_resizer {
#         height: 320
#         width: 320
#       }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         depth: 128
#         class_prediction_bias_init: -4.6
#         conv_hyperparams {
#           activation: RELU_6,
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               stddev: 0.01
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             scale: true,
#             decay: 0.997,
#             epsilon: 0.001,
#           }
#         }
#         num_layers_before_predictor: 4
#         share_prediction_tower: true
#         use_depthwise: true
#         kernel_size: 3
#       }
#     }
#     feature_extractor {
#       type: 'ssd_mobilenet_v2_fpn_keras'
#       use_depthwise: true
#       fpn {
#         min_level: 3
#         max_level: 7
#         additional_layer_depth: 128
#       }
#       min_depth: 16
#       depth_multiplier: 1.0
#       conv_hyperparams {
#         activation: RELU_6,
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           random_normal_initializer {
#             stddev: 0.01
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           scale: true,
#           decay: 0.997,
#           epsilon: 0.001,
#         }
#       }
#       override_base_feature_extractor_hyperparams: true
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid_focal {
#           alpha: 0.25
#           gamma: 2.0
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     normalize_loc_loss_by_codesize: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   fine_tune_checkpoint_version: V2
#   fine_tune_checkpoint: "/content/models/research/pretrained_model/checkpoint/model.ckpt"
#   fine_tune_checkpoint_type: "detection"
#   batch_size: 12
#   sync_replicas: true
#   startup_delay_steps: 0
#   replicas_to_aggregate: 8
#   num_steps: 1000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     random_crop_image {
#       min_object_covered: 0.0
#       min_aspect_ratio: 0.75
#       max_aspect_ratio: 3.0
#       min_area: 0.75
#       max_area: 1.0
#       overlap_thresh: 0.0
#     }
#   }
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         cosine_decay_learning_rate {
#           learning_rate_base: .08
#           total_steps: 50000
#           warmup_learning_rate: .026666
#           warmup_steps: 1000
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
# }
#
# train_input_reader: {
#   label_map_path: "/content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord"
#   }
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
#
# eval_input_reader: {
#   label_map_path: "/content/tensorflow-object-detection-faster-rcnn/data/test/fire_label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/content/tensorflow-object-detection-faster-rcnn/data/test/fire.tfrecord"
#   }
# }

# %%
model_dir = '../../../content/training/'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# ## Run Tensorboard(Optional)

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2023-12-05 17:51:57--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 18.205.222.128, 54.161.241.46, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.205.222.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  41.5MB/s    in 0.3s
#
# 2023-12-05 17:51:58 (41.5 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = model_dir
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %% [markdown]
# ### Get Tensorboard link

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://c6e2-104-154-221-115.ngrok.io

# %% [markdown]
# ## Train the model

# %%
# !pip install lvis
# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_fname} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (0.10.0)
# Requirement already satisfied: Cython>=0.29.12 in /usr/local/lib/python3.10/dist-packages (from lvis) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.4.5)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from lvis) (3.7.1)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis) (4.8.0.76)
# Requirement already satisfied: pyparsing>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (2.8.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (4.45.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (9.4.0)
# Installing collected packages: lvis
# Successfully installed lvis-0.5.3
# 2023-12-05 17:53:24.022443: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-05 17:53:27.600292: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1205 17:53:27.601285 132385150738432 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 1000
# I1205 17:53:27.624561 132385150738432 config_util.py:552] Maybe overwriting train_steps: 1000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1205 17:53:27.624744 132385150738432 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1205 17:53:27.790005 132385150738432 deprecation.py:364] From /content/models/research/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord']
# I1205 17:53:27.797199 132385150738432 dataset_builder.py:162] Reading unweighted datasets: ['/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord']
# I1205 17:53:27.797382 132385150738432 dataset_builder.py:79] Reading record datasets for input file: ['/content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I1205 17:53:27.797462 132385150738432 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1205 17:53:27.797531 132385150738432 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1205 17:53:27.805490 132385150738432 deprecation.py:364] From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1205 17:53:27.823909 132385150738432 deprecation.py:364] From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1205 17:53:34.545645 132385150738432 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W1205 17:53:38.863788 132385150738432 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1205 17:53:40.458659 132385150738432 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I1205 17:53:48.112566 132380310357568 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1205 17:53:59.837206 132380310357568 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.452931 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.455598 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.456669 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.457655 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.461186 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.462087 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.463047 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.463905 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.468290 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 17:54:14.469286 132385150738432 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1205 17:54:15.697729 132380337624640 deprecation.py:569] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I1205 17:54:17.025770 132380337624640 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1205 17:54:25.601606 132380337624640 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1205 17:54:32.352707 132380337624640 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I1205 17:54:40.470720 132380337624640 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.580s
# I1205 17:55:13.324233 132385150738432 model_lib_v2.py:705] Step 100 per-step time 0.580s
# INFO:tensorflow:{'Loss/classification_loss': 0.31962672,
#  'Loss/localization_loss': 0.40045875,
#  'Loss/regularization_loss': 0.15396452,
#  'Loss/total_loss': 0.87405,
#  'learning_rate': 0.0319994}
# I1205 17:55:13.324588 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.31962672,
#  'Loss/localization_loss': 0.40045875,
#  'Loss/regularization_loss': 0.15396452,
#  'Loss/total_loss': 0.87405,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.149s
# I1205 17:55:28.229359 132385150738432 model_lib_v2.py:705] Step 200 per-step time 0.149s
# INFO:tensorflow:{'Loss/classification_loss': 0.23275697,
#  'Loss/localization_loss': 0.29555178,
#  'Loss/regularization_loss': 0.15415284,
#  'Loss/total_loss': 0.6824616,
#  'learning_rate': 0.0373328}
# I1205 17:55:28.229662 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.23275697,
#  'Loss/localization_loss': 0.29555178,
#  'Loss/regularization_loss': 0.15415284,
#  'Loss/total_loss': 0.6824616,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.149s
# I1205 17:55:43.159972 132385150738432 model_lib_v2.py:705] Step 300 per-step time 0.149s
# INFO:tensorflow:{'Loss/classification_loss': 0.23008908,
#  'Loss/localization_loss': 0.32690454,
#  'Loss/regularization_loss': 0.15424298,
#  'Loss/total_loss': 0.7112366,
#  'learning_rate': 0.0426662}
# I1205 17:55:43.160253 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.23008908,
#  'Loss/localization_loss': 0.32690454,
#  'Loss/regularization_loss': 0.15424298,
#  'Loss/total_loss': 0.7112366,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.150s
# I1205 17:55:58.123296 132385150738432 model_lib_v2.py:705] Step 400 per-step time 0.150s
# INFO:tensorflow:{'Loss/classification_loss': 0.19490747,
#  'Loss/localization_loss': 0.22800331,
#  'Loss/regularization_loss': 0.1542954,
#  'Loss/total_loss': 0.5772062,
#  'learning_rate': 0.047999598}
# I1205 17:55:58.123645 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.19490747,
#  'Loss/localization_loss': 0.22800331,
#  'Loss/regularization_loss': 0.1542954,
#  'Loss/total_loss': 0.5772062,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.150s
# I1205 17:56:13.125537 132385150738432 model_lib_v2.py:705] Step 500 per-step time 0.150s
# INFO:tensorflow:{'Loss/classification_loss': 0.21067695,
#  'Loss/localization_loss': 0.26718825,
#  'Loss/regularization_loss': 0.15432304,
#  'Loss/total_loss': 0.63218826,
#  'learning_rate': 0.053333}
# I1205 17:56:13.125844 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.21067695,
#  'Loss/localization_loss': 0.26718825,
#  'Loss/regularization_loss': 0.15432304,
#  'Loss/total_loss': 0.63218826,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.150s
# I1205 17:56:28.146945 132385150738432 model_lib_v2.py:705] Step 600 per-step time 0.150s
# INFO:tensorflow:{'Loss/classification_loss': 0.23896782,
#  'Loss/localization_loss': 0.23458141,
#  'Loss/regularization_loss': 0.15427269,
#  'Loss/total_loss': 0.6278219,
#  'learning_rate': 0.0586664}
# I1205 17:56:28.147293 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.23896782,
#  'Loss/localization_loss': 0.23458141,
#  'Loss/regularization_loss': 0.15427269,
#  'Loss/total_loss': 0.6278219,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.151s
# I1205 17:56:43.291076 132385150738432 model_lib_v2.py:705] Step 700 per-step time 0.151s
# INFO:tensorflow:{'Loss/classification_loss': 0.18897994,
#  'Loss/localization_loss': 0.20855884,
#  'Loss/regularization_loss': 0.15428577,
#  'Loss/total_loss': 0.55182457,
#  'learning_rate': 0.0639998}
# I1205 17:56:43.291381 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.18897994,
#  'Loss/localization_loss': 0.20855884,
#  'Loss/regularization_loss': 0.15428577,
#  'Loss/total_loss': 0.55182457,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.153s
# I1205 17:56:58.573133 132385150738432 model_lib_v2.py:705] Step 800 per-step time 0.153s
# INFO:tensorflow:{'Loss/classification_loss': 0.1709219,
#  'Loss/localization_loss': 0.21390308,
#  'Loss/regularization_loss': 0.15433435,
#  'Loss/total_loss': 0.53915936,
#  'learning_rate': 0.069333196}
# I1205 17:56:58.573446 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.1709219,
#  'Loss/localization_loss': 0.21390308,
#  'Loss/regularization_loss': 0.15433435,
#  'Loss/total_loss': 0.53915936,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.153s
# I1205 17:57:13.831603 132385150738432 model_lib_v2.py:705] Step 900 per-step time 0.153s
# INFO:tensorflow:{'Loss/classification_loss': 0.1910246,
#  'Loss/localization_loss': 0.18299577,
#  'Loss/regularization_loss': 0.15433271,
#  'Loss/total_loss': 0.5283531,
#  'learning_rate': 0.074666604}
# I1205 17:57:13.831909 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.1910246,
#  'Loss/localization_loss': 0.18299577,
#  'Loss/regularization_loss': 0.15433271,
#  'Loss/total_loss': 0.5283531,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.154s
# I1205 17:57:29.270847 132385150738432 model_lib_v2.py:705] Step 1000 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.12201152,
#  'Loss/localization_loss': 0.10006895,
#  'Loss/regularization_loss': 0.15428253,
#  'Loss/total_loss': 0.37636298,
#  'learning_rate': 0.08}
# I1205 17:57:29.271160 132385150738432 model_lib_v2.py:708] {'Loss/classification_loss': 0.12201152,
#  'Loss/localization_loss': 0.10006895,
#  'Loss/regularization_loss': 0.15428253,
#  'Loss/total_loss': 0.37636298,
#  'learning_rate': 0.08}

# %%
# !ls {model_dir}
# Out:
# checkpoint		    ckpt-1.index		ckpt-2.index
# ckpt-1.data-00000-of-00001  ckpt-2.data-00000-of-00001	train

# %% [markdown]
# ## Exporting Trained Inference Graphs
# Once your training job is complete, you need to extract the newly trained inference graph, which will be later used to perform the object detection. We do this again for TFLite. This can be done as follows:

# %%
import os
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.builders import model_builder

# Set paths
output_directory = './fine_tuned_model'
tflite_directory = './fine_tuned_model/tflite'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'ckpt-' in l and '.data' in l]

steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].split('.data')[0]
print(last_model)

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)


# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(pipeline_fname)
model_config = configs['model']
detection_model = model_builder.build(model_config=model_config, is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(model_dir, last_model)).expect_partial()  # Update 'ckpt-XX' to your latest checkpoint

# Function to run inference on a dummy image to build the model
@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# Save the model in SavedModel format
tf.saved_model.save(detection_model, output_directory, signatures=detect_fn.get_concrete_function(tf.TensorSpec(shape=[1, None, None, 3], dtype=tf.float32)))

# Convert to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_saved_model(output_directory)
tflite_model = converter.convert()

# Save the TFLite model
with open(os.path.join(tflite_directory, 'model.tflite'), 'wb') as f:
    f.write(tflite_model)
# Out:
# ckpt-2
# ../../../content/training/ckpt-2
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7bf888165ff0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7bf8ad7063b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf8ad707d60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf8ad707ac0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7bf8ad704100>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c0e2da0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c0e1f00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7bf87c0e0910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c0e35b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c0e2020>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7bf87c0e00d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c0e2380>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c0e14b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c096ce0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c1f0490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c1f09d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c1f1720>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c1f2740>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c1f08b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf88810c4c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf88810e080>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf88d519b70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c15f370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c15e410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c15d0f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c15cbb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c15f6a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c15f5b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c15da80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c15efe0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c15e380>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c15d8d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c15e080>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c0822f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c0811e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf87c080520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf87c082770>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf8ad6c3a60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf8ad6c3d30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf8ad6c2a70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf8ad6c38e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf8ad6c3f10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf8ad6c2b30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7bf8ad6c1f30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7bf8ad6c19c0>, because it is not built.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.

# %%
# Verify model was built
import os

print(os.listdir(output_directory))
print(os.listdir(tflite_directory))

full_paths_output_dir = [os.path.join(os.path.abspath(output_directory), f) for f in os.listdir(output_directory)]
print(full_paths_output_dir)

full_paths_tflite_dir = [os.path.join(os.path.abspath(tflite_directory), f) for f in os.listdir(tflite_directory)]
print(full_paths_tflite_dir)
# Out:
# ['saved_model.pb', 'variables', 'assets', 'fingerprint.pb', 'tflite']
# ['model.tflite']
# ['/content/models/research/fine_tuned_model/saved_model.pb', '/content/models/research/fine_tuned_model/variables', '/content/models/research/fine_tuned_model/assets', '/content/models/research/fine_tuned_model/fingerprint.pb', '/content/models/research/fine_tuned_model/tflite']
# ['/content/models/research/fine_tuned_model/tflite/model.tflite']

# %% [markdown]
# ## Download the model `.pb` file

# %%
import os

saved_model_pb_fname = os.path.join(os.path.abspath(output_directory), "saved_model.pb")

# Check if the SavedModel file exists
print(saved_model_pb_fname)
assert os.path.isfile(saved_model_pb_fname), '`{}` does not exist.'.format(saved_model_pb_fname)
# Out:
# /content/models/research/fine_tuned_model/saved_model.pb

# %%
# !ls -alh {saved_model_pb_fname}
# Out:
# -rw-r--r-- 1 root root 4.6M Dec  5 18:42 /content/models/research/fine_tuned_model/saved_model.pb

# %% [markdown]
# ### Upload the `.pb` file to your Google Drive
# Then download it from your Google Drive to local file system.
#
# During this step, you will be prompted to enter the token.

# %%
# # Install the PyDrive wrapper & import libraries.
# # This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# # Authenticate and create the PyDrive client.
# # This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

fname = os.path.basename(saved_model_pb_fname)
# # Create & upload a text file.
uploaded = drive.CreateFile({'title': fname})
uploaded.SetContentFile(saved_model_pb_fname)
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1-ReKk0vVB9Eo3DO7CFsEAvkusThVZ3c0

# %% [markdown]
# ### Download the `.pb` file directly to your local file system
# This method may not be stable when downloading large files like the model `.pb` file. Try **option 1** instead if not working.

# %%
from google.colab import files
files.download(saved_model_pb_fname)

# %% [markdown]
# ### Download CONTENT files as a zip and upload to Github
#
# We have created many changes in the config files as well as in datasets, checkpoint generation, and model generation, please upload these changes to Github: [git@github.com:DivyaAmirtharaj/cs249_final_project.git](https://)

# %%
# Zip all files and download
# !zip -r /content/smoke_detection_tfmodel.zip /content

from google.colab import files
files.download("/content/smoke_detection_tfmodel.zip")
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 22%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2023.12.04/ (stored 0%)
#   adding: content/.config/logs/2023.12.04/14.27.00.107426.log (deflated 56%)
#   adding: content/.config/logs/2023.12.04/14.23.59.638040.log (deflated 86%)
#   adding: content/.config/logs/2023.12.04/14.26.48.840108.log (deflated 58%)
#   adding: content/.config/logs/2023.12.04/14.20.49.627769.log (deflated 91%)
#   adding: content/.config/logs/2023.12.04/14.23.49.652015.log (deflated 58%)
#   adding: content/.config/logs/2023.12.04/14.26.59.279282.log (deflated 57%)
#   adding: content/.config/logs/2023.12.05/ (stored 0%)
#   adding: content/.config/logs/2023.12.05/19.03.16.084056.log (deflated 57%)
#   adding: content/Wildfire/ (stored 0%)
#   adding: content/Wildfire/test/ (stored 0%)
#   adding: content/Wildfire/test/fire.tfrecord (deflated 2%)
#   adding: content/Wildfire/test/fire_label_map.pbtxt (deflated 28%)
#   adding: content/Wildfire/train/ (stored 0%)
#   adding: content/Wildfire/train/fire.tfrecord (deflated 2%)
#   adding: content/Wildfire/train/fire_label_map.pbtxt (deflated 28%)
#   adding: content/Wildfire/README.dataset.txt (deflated 14%)
#   adding: content/Wildfire/valid/ (stored 0%)
#   adding: content/Wildfire/valid/fire.tfrecord (deflated 2%)
#   adding: content/Wildfire/valid/fire_label_map.pbtxt (deflated 28%)
#   adding: content/Wildfire/README.roboflow.txt (deflated 45%)
#   adding: content/models/ (stored 0%)
#   adding: content/models/.git/ (stored 0%)
#   adding: content/models/.git/refs/ (stored 0%)
#   adding: content/models/.git/refs/heads/ (stored 0%)
#   adding: content/models/.git/refs/heads/master (stored 0%)
#   adding: content/models/.git/refs/remotes/ (stored 0%)
#   adding: content/models/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/models/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/models/.git/refs/tags/ (stored 0%)
#   adding: content/models/.git/info/ (stored 0%)
#   adding: content/models/.git/info/exclude (deflated 28%)
#   adding: content/models/.git/hooks/ (stored 0%)
#   adding: content/models/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/models/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/models/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/models/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/models/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/models/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/models/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/models/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/models/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/models/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/models/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/models/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/models/.git/hooks/update.sample (deflated 68%)
#   adding: content/models/.git/description (deflated 14%)
#   adding: content/models/.git/packed-refs (deflated 63%)
#   adding: content/models/.git/index (deflated 67%)
#   adding: content/models/.git/objects/ (stored 0%)
#   adding: content/models/.git/objects/pack/ (stored 0%)
#   adding: content/models/.git/objects/pack/pack-9fe358e9d332fd5cfa022a6583f9a2d9cb0279da.idx (deflated 1%)
#   adding: content/models/.git/objects/pack/pack-9fe358e9d332fd5cfa022a6583f9a2d9cb0279da.pack (deflated 0%)
#   adding: content/models/.git/objects/info/ (stored 0%)
#   adding: content/models/.git/config (deflated 34%)
#   adding: content/models/.git/branches/ (stored 0%)
#   adding: content/models/.git/logs/ (stored 0%)
#   adding: content/models/.git/logs/refs/ (stored 0%)
#   adding: content/models/.git/logs/refs/heads/ (stored 0%)
#   adding: content/models/.git/logs/refs/heads/master (deflated 29%)
#   adding: content/models/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/models/.git/logs/refs/remotes/origin/HEAD (deflated 29%)
#   adding: content/models/.git/logs/HEAD (deflated 29%)
#   adding: content/models/.git/HEAD (stored 0%)
#   adding: content/models/research/ (stored 0%)
#   adding: content/models/research/rebar/ (stored 0%)
#   adding: content/models/research/rebar/rebar_train.py (deflated 65%)
#   adding: content/models/research/rebar/config.py (deflated 45%)
#   adding: content/models/research/rebar/rebar.py (deflated 81%)
#   adding: content/models/research/rebar/README.md (deflated 57%)
#   adding: content/models/research/rebar/logger.py (deflated 47%)
#   adding: content/models/research/rebar/datasets.py (deflated 60%)
#   adding: content/models/research/rebar/utils.py (deflated 57%)
#   adding: content/models/research/rebar/download_data.py (deflated 60%)
#   adding: content/models/research/lstm_object_detection/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/builders/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/builders/graph_rewriter_builder_test.py (deflated 71%)
#   adding: content/models/research/lstm_object_detection/builders/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/builders/graph_rewriter_builder.py (deflated 65%)
#   adding: content/models/research/lstm_object_detection/meta_architectures/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/meta_architectures/lstm_ssd_meta_arch.py (deflated 74%)
#   adding: content/models/research/lstm_object_detection/meta_architectures/lstm_ssd_meta_arch_test.py (deflated 76%)
#   adding: content/models/research/lstm_object_detection/meta_architectures/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/trainer.py (deflated 70%)
#   adding: content/models/research/lstm_object_detection/utils/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/utils/config_util.py (deflated 70%)
#   adding: content/models/research/lstm_object_detection/utils/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/utils/config_util_test.py (deflated 71%)
#   adding: content/models/research/lstm_object_detection/model_builder.py (deflated 74%)
#   adding: content/models/research/lstm_object_detection/g3doc/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/g3doc/Interleaved_Intro.png (deflated 1%)
#   adding: content/models/research/lstm_object_detection/g3doc/lstm_ssd_intro.png (deflated 1%)
#   adding: content/models/research/lstm_object_detection/g3doc/exporting_models.md (deflated 63%)
#   adding: content/models/research/lstm_object_detection/export_tflite_lstd_model.py (deflated 56%)
#   adding: content/models/research/lstm_object_detection/export_tflite_lstd_graph_lib.py (deflated 72%)
#   adding: content/models/research/lstm_object_detection/configs/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/configs/lstm_ssd_interleaved_mobilenet_v2_imagenet.config (deflated 67%)
#   adding: content/models/research/lstm_object_detection/configs/lstm_ssd_mobilenet_v1_imagenet.config (deflated 66%)
#   adding: content/models/research/lstm_object_detection/test_tflite_model.py (deflated 52%)
#   adding: content/models/research/lstm_object_detection/inputs/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/inputs/tf_sequence_example_decoder_test.py (deflated 70%)
#   adding: content/models/research/lstm_object_detection/inputs/seq_dataset_builder_test.py (deflated 74%)
#   adding: content/models/research/lstm_object_detection/inputs/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/inputs/seq_dataset_builder.py (deflated 73%)
#   adding: content/models/research/lstm_object_detection/inputs/tf_sequence_example_decoder.py (deflated 72%)
#   adding: content/models/research/lstm_object_detection/protos/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/protos/quant_overrides.proto (deflated 58%)
#   adding: content/models/research/lstm_object_detection/protos/input_reader_google.proto (deflated 51%)
#   adding: content/models/research/lstm_object_detection/protos/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/protos/pipeline.proto (deflated 61%)
#   adding: content/models/research/lstm_object_detection/models/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/models/lstm_ssd_mobilenet_v1_feature_extractor.py (deflated 69%)
#   adding: content/models/research/lstm_object_detection/models/mobilenet_defs.py (deflated 72%)
#   adding: content/models/research/lstm_object_detection/models/lstm_ssd_interleaved_mobilenet_v2_feature_extractor.py (deflated 72%)
#   adding: content/models/research/lstm_object_detection/models/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/models/lstm_ssd_interleaved_mobilenet_v2_feature_extractor_test.py (deflated 80%)
#   adding: content/models/research/lstm_object_detection/models/lstm_ssd_mobilenet_v1_feature_extractor_test.py (deflated 70%)
#   adding: content/models/research/lstm_object_detection/models/mobilenet_defs_test.py (deflated 79%)
#   adding: content/models/research/lstm_object_detection/README.md (deflated 49%)
#   adding: content/models/research/lstm_object_detection/train.py (deflated 66%)
#   adding: content/models/research/lstm_object_detection/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/metrics/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/metrics/coco_evaluation_all_frames.py (deflated 71%)
#   adding: content/models/research/lstm_object_detection/metrics/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/metrics/coco_evaluation_all_frames_test.py (deflated 82%)
#   adding: content/models/research/lstm_object_detection/model_builder_test.py (deflated 81%)
#   adding: content/models/research/lstm_object_detection/eval.py (deflated 64%)
#   adding: content/models/research/lstm_object_detection/tflite/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/conversion_utils_test.cc (deflated 79%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/ssd_utils.cc (deflated 80%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/ssd_utils.h (deflated 72%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/conversion_utils.h (deflated 52%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/file_utils.h (deflated 53%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/BUILD (deflated 71%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/file_utils.cc (deflated 54%)
#   adding: content/models/research/lstm_object_detection/tflite/utils/conversion_utils.cc (deflated 62%)
#   adding: content/models/research/lstm_object_detection/tflite/mobile_lstd_tflite_client.h (deflated 61%)
#   adding: content/models/research/lstm_object_detection/tflite/WORKSPACE (deflated 67%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/detections.proto (deflated 49%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/mobile_ssd_client_options.proto (deflated 60%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/proto_config.asciipb (deflated 12%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/anchor_generation_options.proto (deflated 56%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/labelmap.proto (deflated 52%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/BUILD (deflated 78%)
#   adding: content/models/research/lstm_object_detection/tflite/protos/box_encodings.proto (deflated 67%)
#   adding: content/models/research/lstm_object_detection/tflite/mobile_lstd_tflite_client.cc (deflated 77%)
#   adding: content/models/research/lstm_object_detection/tflite/mobile_ssd_tflite_client.h (deflated 61%)
#   adding: content/models/research/lstm_object_detection/tflite/mobile_ssd_client.h (deflated 65%)
#   adding: content/models/research/lstm_object_detection/tflite/mobile_ssd_tflite_client.cc (deflated 76%)
#   adding: content/models/research/lstm_object_detection/tflite/BUILD (deflated 77%)
#   adding: content/models/research/lstm_object_detection/tflite/mobile_ssd_client.cc (deflated 70%)
#   adding: content/models/research/lstm_object_detection/lstm/ (stored 0%)
#   adding: content/models/research/lstm_object_detection/lstm/lstm_cells.py (deflated 79%)
#   adding: content/models/research/lstm_object_detection/lstm/rnn_decoder_test.py (deflated 84%)
#   adding: content/models/research/lstm_object_detection/lstm/utils_test.py (deflated 82%)
#   adding: content/models/research/lstm_object_detection/lstm/lstm_cells_test.py (deflated 90%)
#   adding: content/models/research/lstm_object_detection/lstm/__init__.py (stored 0%)
#   adding: content/models/research/lstm_object_detection/lstm/utils.py (deflated 73%)
#   adding: content/models/research/lstm_object_detection/lstm/rnn_decoder.py (deflated 71%)
#   adding: content/models/research/lstm_object_detection/evaluator.py (deflated 71%)
#   adding: content/models/research/lstm_object_detection/export_tflite_lstd_graph.py (deflated 64%)
#   adding: content/models/research/fine_tuned_model.tar.gz (deflated 1%)
#   adding: content/models/research/fine_tuned_model/ (stored 0%)
#   adding: content/models/research/fine_tuned_model/saved_model.pb (deflated 92%)
#   adding: content/models/research/fine_tuned_model/variables/ (stored 0%)
#   adding: content/models/research/fine_tuned_model/variables/variables.index (deflated 78%)
#   adding: content/models/research/fine_tuned_model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: content/models/research/fine_tuned_model/assets/ (stored 0%)
#   adding: content/models/research/fine_tuned_model/fingerprint.pb (stored 0%)
#   adding: content/models/research/fine_tuned_model/tflite/ (stored 0%)
#   adding: content/models/research/fine_tuned_model/tflite/model.tflite (deflated 10%)
#   adding: content/models/research/ngrok (deflated 54%)
#   adding: content/models/research/marco/ (stored 0%)
#   adding: content/models/research/marco/jpeg2json.py (deflated 41%)
#   adding: content/models/research/marco/request.json (deflated 25%)
#   adding: content/models/research/marco/README.md (deflated 55%)
#   adding: content/models/research/marco/Automated_Marco.py (deflated 55%)
#   adding: content/models/research/vid2depth/ (stored 0%)
#   adding: content/models/research/vid2depth/ops/ (stored 0%)
#   adding: content/models/research/vid2depth/ops/pcl_demo.cc (deflated 70%)
#   adding: content/models/research/vid2depth/ops/icp_test.py (deflated 80%)
#   adding: content/models/research/vid2depth/ops/icp_util.py (deflated 71%)
#   adding: content/models/research/vid2depth/ops/icp_train_demo.py (deflated 64%)
#   adding: content/models/research/vid2depth/ops/__init__.py (deflated 43%)
#   adding: content/models/research/vid2depth/ops/icp_op_kernel.cc (deflated 72%)
#   adding: content/models/research/vid2depth/ops/icp_op.py (deflated 46%)
#   adding: content/models/research/vid2depth/ops/icp_grad_test.py (deflated 72%)
#   adding: content/models/research/vid2depth/ops/icp_grad.py (deflated 53%)
#   adding: content/models/research/vid2depth/ops/testdata/ (stored 0%)
#   adding: content/models/research/vid2depth/ops/testdata/pointcloud.npy (deflated 23%)
#   adding: content/models/research/vid2depth/ops/BUILD (deflated 78%)
#   adding: content/models/research/vid2depth/inference.py (deflated 64%)
#   adding: content/models/research/vid2depth/reader.py (deflated 70%)
#   adding: content/models/research/vid2depth/WORKSPACE (deflated 64%)
#   adding: content/models/research/vid2depth/nets.py (deflated 72%)
#   adding: content/models/research/vid2depth/util.py (deflated 58%)
#   adding: content/models/research/vid2depth/dataset/ (stored 0%)
#   adding: content/models/research/vid2depth/dataset/gen_data.py (deflated 67%)
#   adding: content/models/research/vid2depth/dataset/kitti/ (stored 0%)
#   adding: content/models/research/vid2depth/dataset/kitti/test_scenes_eigen.txt (deflated 81%)
#   adding: content/models/research/vid2depth/dataset/kitti/test_files_stereo.txt (deflated 92%)
#   adding: content/models/research/vid2depth/dataset/kitti/test_files_eigen.txt (deflated 94%)
#   adding: content/models/research/vid2depth/dataset/kitti/static_frames.txt (deflated 94%)
#   adding: content/models/research/vid2depth/dataset/kitti/test_scenes_stereo.txt (deflated 83%)
#   adding: content/models/research/vid2depth/dataset/dataset_loader.py (deflated 78%)
#   adding: content/models/research/vid2depth/dataset/__init__.py (deflated 43%)
#   adding: content/models/research/vid2depth/repo.bzl (deflated 57%)
#   adding: content/models/research/vid2depth/project.py (deflated 68%)
#   adding: content/models/research/vid2depth/third_party/ (stored 0%)
#   adding: content/models/research/vid2depth/third_party/pcl.BUILD (deflated 80%)
#   adding: content/models/research/vid2depth/third_party/hdf5.BUILD (deflated 66%)
#   adding: content/models/research/vid2depth/third_party/eigen.BUILD (deflated 43%)
#   adding: content/models/research/vid2depth/third_party/flann.BUILD (deflated 70%)
#   adding: content/models/research/vid2depth/third_party/BUILD (stored 0%)
#   adding: content/models/research/vid2depth/.bazelrc (deflated 31%)
#   adding: content/models/research/vid2depth/README.md (deflated 65%)
#   adding: content/models/research/vid2depth/train.py (deflated 65%)
#   adding: content/models/research/vid2depth/model.py (deflated 74%)
#   adding: content/models/research/vid2depth/BUILD (deflated 11%)
#   adding: content/models/research/pretrained_model/ (stored 0%)
#   adding: content/models/research/pretrained_model/checkpoint/ (stored 0%)
#   adding: content/models/research/pretrained_model/checkpoint/model.ckpt.data-00000-of-00001 (deflated 8%)
#   adding: content/models/research/pretrained_model/checkpoint/checkpoint (deflated 41%)
#   adding: content/models/research/pretrained_model/checkpoint/model.ckpt.index (deflated 14%)
#   adding: content/models/research/pretrained_model/saved_model/ (stored 0%)
#   adding: content/models/research/pretrained_model/saved_model/saved_model.pb (deflated 93%)
#   adding: content/models/research/pretrained_model/saved_model/variables/ (stored 0%)
#   adding: content/models/research/pretrained_model/saved_model/variables/variables.index (deflated 16%)
#   adding: content/models/research/pretrained_model/saved_model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/models/research/pretrained_model/pipeline.config (deflated 68%)
#   adding: content/models/research/object_detection/ (stored 0%)
#   adding: content/models/research/object_detection/eval_util.py (deflated 78%)
#   adding: content/models/research/object_detection/dataset_tools/ (stored 0%)
#   adding: content/models/research/object_detection/dataset_tools/create_oid_tf_record.py (deflated 63%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/ (stored 0%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/create_cococameratraps_tfexample_tf2_test.py (deflated 76%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/generate_detection_data_tf2_test.py (deflated 71%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/add_context_to_examples_tf2_test.py (deflated 80%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/generate_detection_data.py (deflated 72%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/generate_embedding_data_tf2_test.py (deflated 75%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/create_cococameratraps_tfexample_main.py (deflated 70%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/generate_embedding_data.py (deflated 71%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/dataset_tools/context_rcnn/add_context_to_examples.py (deflated 80%)
#   adding: content/models/research/object_detection/dataset_tools/tf_record_creation_util_test.py (deflated 52%)
#   adding: content/models/research/object_detection/dataset_tools/download_and_preprocess_ava.sh (deflated 51%)
#   adding: content/models/research/object_detection/dataset_tools/create_pascal_tf_record.py (deflated 65%)
#   adding: content/models/research/object_detection/dataset_tools/create_pycocotools_package.sh (deflated 54%)
#   adding: content/models/research/object_detection/dataset_tools/oid_tfrecord_creation.py (deflated 74%)
#   adding: content/models/research/object_detection/dataset_tools/seq_example_util.py (deflated 76%)
#   adding: content/models/research/object_detection/dataset_tools/seq_example_util_test.py (deflated 87%)
#   adding: content/models/research/object_detection/dataset_tools/create_kitti_tf_record.py (deflated 72%)
#   adding: content/models/research/object_detection/dataset_tools/create_pet_tf_record.py (deflated 69%)
#   adding: content/models/research/object_detection/dataset_tools/oid_hierarchical_labels_expansion_test.py (deflated 72%)
#   adding: content/models/research/object_detection/dataset_tools/oid_tfrecord_creation_test.py (deflated 82%)
#   adding: content/models/research/object_detection/dataset_tools/oid_hierarchical_labels_expansion.py (deflated 70%)
#   adding: content/models/research/object_detection/dataset_tools/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/dataset_tools/densepose/ (stored 0%)
#   adding: content/models/research/object_detection/dataset_tools/densepose/UV_symmetry_transforms.mat (deflated 96%)
#   adding: content/models/research/object_detection/dataset_tools/create_coco_tf_record.py (deflated 77%)
#   adding: content/models/research/object_detection/dataset_tools/create_coco_tf_record_test.py (deflated 84%)
#   adding: content/models/research/object_detection/dataset_tools/create_kitti_tf_record_test.py (deflated 73%)
#   adding: content/models/research/object_detection/dataset_tools/download_and_preprocess_mscoco.sh (deflated 61%)
#   adding: content/models/research/object_detection/dataset_tools/create_pascal_tf_record_test.py (deflated 69%)
#   adding: content/models/research/object_detection/dataset_tools/tf_record_creation_util.py (deflated 50%)
#   adding: content/models/research/object_detection/dataset_tools/create_ava_actions_tf_record.py (deflated 74%)
#   adding: content/models/research/object_detection/builders/ (stored 0%)
#   adding: content/models/research/object_detection/builders/preprocessor_builder_test.py (deflated 89%)
#   adding: content/models/research/object_detection/builders/calibration_builder.py (deflated 73%)
#   adding: content/models/research/object_detection/builders/model_builder_tf1_test.py (deflated 58%)
#   adding: content/models/research/object_detection/builders/optimizer_builder.py (deflated 79%)
#   adding: content/models/research/object_detection/builders/post_processing_builder.py (deflated 70%)
#   adding: content/models/research/object_detection/builders/region_similarity_calculator_builder_test.py (deflated 72%)
#   adding: content/models/research/object_detection/builders/model_builder.py (deflated 83%)
#   adding: content/models/research/object_detection/builders/model_builder_tf2_test.py (deflated 81%)
#   adding: content/models/research/object_detection/builders/anchor_generator_builder_test.py (deflated 85%)
#   adding: content/models/research/object_detection/builders/optimizer_builder_tf2_test.py (deflated 71%)
#   adding: content/models/research/object_detection/builders/image_resizer_builder.py (deflated 73%)
#   adding: content/models/research/object_detection/builders/matcher_builder.py (deflated 61%)
#   adding: content/models/research/object_detection/builders/hyperparams_builder_test.py (deflated 92%)
#   adding: content/models/research/object_detection/builders/image_resizer_builder_test.py (deflated 82%)
#   adding: content/models/research/object_detection/builders/calibration_builder_test.py (deflated 78%)
#   adding: content/models/research/object_detection/builders/dataset_builder.py (deflated 71%)
#   adding: content/models/research/object_detection/builders/post_processing_builder_test.py (deflated 82%)
#   adding: content/models/research/object_detection/builders/input_reader_builder_tf1_test.py (deflated 80%)
#   adding: content/models/research/object_detection/builders/matcher_builder_test.py (deflated 74%)
#   adding: content/models/research/object_detection/builders/preprocessor_builder.py (deflated 81%)
#   adding: content/models/research/object_detection/builders/target_assigner_builder_test.py (deflated 56%)
#   adding: content/models/research/object_detection/builders/decoder_builder_test.py (deflated 75%)
#   adding: content/models/research/object_detection/builders/decoder_builder.py (deflated 67%)
#   adding: content/models/research/object_detection/builders/anchor_generator_builder.py (deflated 75%)
#   adding: content/models/research/object_detection/builders/__pycache__/ (stored 0%)
#   adding: content/models/research/object_detection/builders/__pycache__/matcher_builder.cpython-310.pyc (deflated 44%)
#   adding: content/models/research/object_detection/builders/__pycache__/region_similarity_calculator_builder.cpython-310.pyc (deflated 57%)
#   adding: content/models/research/object_detection/builders/__pycache__/losses_builder.cpython-310.pyc (deflated 61%)
#   adding: content/models/research/object_detection/builders/__pycache__/optimizer_builder.cpython-310.pyc (deflated 58%)
#   adding: content/models/research/object_detection/builders/__pycache__/calibration_builder.cpython-310.pyc (deflated 60%)
#   adding: content/models/research/object_detection/builders/__pycache__/post_processing_builder.cpython-310.pyc (deflated 59%)
#   adding: content/models/research/object_detection/builders/__pycache__/box_predictor_builder.cpython-310.pyc (deflated 75%)
#   adding: content/models/research/object_detection/builders/__pycache__/box_coder_builder.cpython-310.pyc (deflated 47%)
#   adding: content/models/research/object_detection/builders/__pycache__/hyperparams_builder.cpython-310.pyc (deflated 62%)
#   adding: content/models/research/object_detection/builders/__pycache__/decoder_builder.cpython-310.pyc (deflated 46%)
#   adding: content/models/research/object_detection/builders/__pycache__/__init__.cpython-310.pyc (deflated 23%)
#   adding: content/models/research/object_detection/builders/__pycache__/image_resizer_builder.cpython-310.pyc (deflated 54%)
#   adding: content/models/research/object_detection/builders/__pycache__/graph_rewriter_builder.cpython-310.pyc (deflated 41%)
#   adding: content/models/research/object_detection/builders/__pycache__/model_builder.cpython-310.pyc (deflated 62%)
#   adding: content/models/research/object_detection/builders/__pycache__/preprocessor_builder.cpython-310.pyc (deflated 59%)
#   adding: content/models/research/object_detection/builders/__pycache__/dataset_builder.cpython-310.pyc (deflated 56%)
#   adding: content/models/research/object_detection/builders/__pycache__/anchor_generator_builder.cpython-310.pyc (deflated 52%)
#   adding: content/models/research/object_detection/builders/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/builders/box_coder_builder.py (deflated 69%)
#   adding: content/models/research/object_detection/builders/model_builder_test.py (deflated 80%)
#   adding: content/models/research/object_detection/builders/graph_rewriter_builder.py (deflated 55%)
#   adding: content/models/research/object_detection/builders/losses_builder_test.py (deflated 90%)
#   adding: content/models/research/object_detection/builders/box_predictor_builder_test.py (deflated 90%)
#   adding: content/models/research/object_detection/builders/losses_builder.py (deflated 79%)
#   adding: content/models/research/object_detection/builders/hyperparams_builder.py (deflated 75%)
#   adding: content/models/research/object_detection/builders/dataset_builder_test.py (deflated 82%)
#   adding: content/models/research/object_detection/builders/box_predictor_builder.py (deflated 88%)
#   adding: content/models/research/object_detection/builders/input_reader_builder.py (deflated 65%)
#   adding: content/models/research/object_detection/builders/graph_rewriter_builder_tf1_test.py (deflated 66%)
#   adding: content/models/research/object_detection/builders/box_coder_builder_test.py (deflated 80%)
#   adding: content/models/research/object_detection/builders/optimizer_builder_tf1_test.py (deflated 79%)
#   adding: content/models/research/object_detection/builders/region_similarity_calculator_builder.py (deflated 67%)
#   adding: content/models/research/object_detection/builders/target_assigner_builder.py (deflated 60%)
#   adding: content/models/research/object_detection/meta_architectures/ (stored 0%)
#   adding: content/models/research/object_detection/meta_architectures/center_net_meta_arch_tf2_test.py (deflated 86%)
#   adding: content/models/research/object_detection/meta_architectures/context_rcnn_lib_tf2_test.py (deflated 70%)
#   adding: content/models/research/object_detection/meta_architectures/context_rcnn_lib_tf2.py (deflated 72%)
#   adding: content/models/research/object_detection/meta_architectures/deepmac_meta_arch.py (deflated 78%)
#   adding: content/models/research/object_detection/meta_architectures/rfcn_meta_arch_test.py (deflated 61%)
#   adding: content/models/research/object_detection/meta_architectures/ssd_meta_arch_test_lib.py (deflated 70%)
#   adding: content/models/research/object_detection/meta_architectures/context_rcnn_lib.py (deflated 74%)
#   adding: content/models/research/object_detection/meta_architectures/center_net_meta_arch.py (deflated 81%)
#   adding: content/models/research/object_detection/meta_architectures/context_rcnn_meta_arch.py (deflated 78%)
#   adding: content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch.py (deflated 81%)
#   adding: content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch_test.py (deflated 86%)
#   adding: content/models/research/object_detection/meta_architectures/ssd_meta_arch_test.py (deflated 86%)
#   adding: content/models/research/object_detection/meta_architectures/faster_rcnn_meta_arch_test_lib.py (deflated 87%)
#   adding: content/models/research/object_detection/meta_architectures/context_rcnn_meta_arch_test.py (deflated 78%)
#   adding: content/models/research/object_detection/meta_architectures/context_rcnn_lib_tf1_test.py (deflated 78%)
#   adding: content/models/research/object_detection/meta_architectures/ssd_meta_arch.py (deflated 79%)
#   adding: content/models/research/object_detection/meta_architectures/deepmac_meta_arch_test.py (deflated 84%)
#   adding: content/models/research/object_detection/meta_architectures/rfcn_meta_arch.py (deflated 72%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/ (stored 0%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/context_rcnn_meta_arch.cpython-310.pyc (deflated 70%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/ssd_meta_arch.cpython-310.pyc (deflated 66%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/center_net_meta_arch.cpython-310.pyc (deflated 70%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/deepmac_meta_arch.cpython-310.pyc (deflated 62%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/rfcn_meta_arch.cpython-310.pyc (deflated 64%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/context_rcnn_lib_tf2.cpython-310.pyc (deflated 57%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/context_rcnn_lib.cpython-310.pyc (deflated 60%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/__init__.cpython-310.pyc (deflated 25%)
#   adding: content/models/research/object_detection/meta_architectures/__pycache__/faster_rcnn_meta_arch.cpython-310.pyc (deflated 71%)
#   adding: content/models/research/object_detection/meta_architectures/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/tpu_exporters/ (stored 0%)
#   adding: content/models/research/object_detection/tpu_exporters/export_saved_model_tpu_lib.py (deflated 73%)
#   adding: content/models/research/object_detection/tpu_exporters/export_saved_model_tpu.py (deflated 56%)
#   adding: content/models/research/object_detection/tpu_exporters/ssd.py (deflated 70%)
#   adding: content/models/research/object_detection/tpu_exporters/utils_test.py (deflated 58%)
#   adding: content/models/research/object_detection/tpu_exporters/faster_rcnn.py (deflated 69%)
#   adding: content/models/research/object_detection/tpu_exporters/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/tpu_exporters/utils.py (deflated 54%)
#   adding: content/models/research/object_detection/tpu_exporters/export_saved_model_tpu_lib_tf1_test.py (deflated 56%)
#   adding: content/models/research/object_detection/tpu_exporters/testdata/ (stored 0%)
#   adding: content/models/research/object_detection/tpu_exporters/testdata/faster_rcnn/ (stored 0%)
#   adding: content/models/research/object_detection/tpu_exporters/testdata/faster_rcnn/faster_rcnn_resnet101_atrous_coco.config (deflated 64%)
#   adding: content/models/research/object_detection/tpu_exporters/testdata/ssd/ (stored 0%)
#   adding: content/models/research/object_detection/tpu_exporters/testdata/ssd/ssd_pipeline.config (deflated 68%)
#   adding: content/models/research/object_detection/tpu_exporters/testdata/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/dockerfiles/ (stored 0%)
#   adding: content/models/research/object_detection/dockerfiles/tf2_ai_platform/ (stored 0%)
#   adding: content/models/research/object_detection/dockerfiles/tf2_ai_platform/Dockerfile (deflated 54%)
#   adding: content/models/research/object_detection/dockerfiles/tf2/ (stored 0%)
#   adding: content/models/research/object_detection/dockerfiles/tf2/Dockerfile (deflated 50%)
#   adding: content/models/research/object_detection/dockerfiles/tf2/README.md (deflated 30%)
#   adding: content/models/research/object_detection/dockerfiles/tf1/ (stored 0%)
#   adding: content/models/research/object_detection/dockerfiles/tf1/Dockerfile (deflated 50%)
#   adding: content/models/research/object_detection/dockerfiles/tf1/README.md (deflated 30%)
#   adding: content/models/research/object_detection/dockerfiles/android/ (stored 0%)
#   adding: content/models/research/object_detection/dockerfiles/android/Dockerfile (deflated 61%)
#   adding: content/models/research/object_detection/dockerfiles/android/README.md (deflated 55%)
#   adding: content/models/research/object_detection/utils/ (stored 0%)
#   adding: content/models/research/object_detection/utils/variables_helper_tf1_test.py (deflated 82%)
#   adding: content/models/research/object_detection/utils/vrd_evaluation_test.py (deflated 86%)
#   adding: content/models/research/object_detection/utils/test_utils_test.py (deflated 66%)
#   adding: content/models/research/object_detection/utils/metrics.py (deflated 69%)
#   adding: content/models/research/object_detection/utils/label_map_util_test.py (deflated 84%)
#   adding: content/models/research/object_detection/utils/np_box_list_ops.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/shape_utils.py (deflated 71%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list_ops.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/patch_ops.py (deflated 60%)
#   adding: content/models/research/object_detection/utils/json_utils_test.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/np_mask_ops.py (deflated 72%)
#   adding: content/models/research/object_detection/utils/learning_schedules.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/vrd_evaluation.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/ops_test.py (deflated 87%)
#   adding: content/models/research/object_detection/utils/variables_helper.py (deflated 67%)
#   adding: content/models/research/object_detection/utils/visualization_utils.py (deflated 79%)
#   adding: content/models/research/object_detection/utils/spatial_transform_ops_test.py (deflated 87%)
#   adding: content/models/research/object_detection/utils/np_box_list_test.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/static_shape.py (deflated 66%)
#   adding: content/models/research/object_detection/utils/autoaugment_utils.py (deflated 77%)
#   adding: content/models/research/object_detection/utils/metrics_test.py (deflated 77%)
#   adding: content/models/research/object_detection/utils/shape_utils_test.py (deflated 83%)
#   adding: content/models/research/object_detection/utils/np_box_list_ops_test.py (deflated 85%)
#   adding: content/models/research/object_detection/utils/static_shape_test.py (deflated 63%)
#   adding: content/models/research/object_detection/utils/np_mask_ops_test.py (deflated 74%)
#   adding: content/models/research/object_detection/utils/spatial_transform_ops.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/config_util.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/colab_utils.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/category_util.py (deflated 56%)
#   adding: content/models/research/object_detection/utils/object_detection_evaluation.py (deflated 83%)
#   adding: content/models/research/object_detection/utils/bifpn_utils.py (deflated 75%)
#   adding: content/models/research/object_detection/utils/per_image_vrd_evaluation.py (deflated 78%)
#   adding: content/models/research/object_detection/utils/context_manager.py (deflated 48%)
#   adding: content/models/research/object_detection/utils/category_util_test.py (deflated 59%)
#   adding: content/models/research/object_detection/utils/np_box_list.py (deflated 64%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list_test.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/object_detection_evaluation_test.py (deflated 89%)
#   adding: content/models/research/object_detection/utils/test_case_test.py (deflated 67%)
#   adding: content/models/research/object_detection/utils/per_image_evaluation_test.py (deflated 92%)
#   adding: content/models/research/object_detection/utils/test_case.py (deflated 80%)
#   adding: content/models/research/object_detection/utils/per_image_vrd_evaluation_test.py (deflated 72%)
#   adding: content/models/research/object_detection/utils/json_utils.py (deflated 60%)
#   adding: content/models/research/object_detection/utils/np_box_ops_test.py (deflated 65%)
#   adding: content/models/research/object_detection/utils/label_map_util.py (deflated 73%)
#   adding: content/models/research/object_detection/utils/model_util_tf2_test.py (deflated 56%)
#   adding: content/models/research/object_detection/utils/dataset_util_test.py (deflated 50%)
#   adding: content/models/research/object_detection/utils/dataset_util.py (deflated 59%)
#   adding: content/models/research/object_detection/utils/__pycache__/ (stored 0%)
#   adding: content/models/research/object_detection/utils/__pycache__/patch_ops.cpython-310.pyc (deflated 48%)
#   adding: content/models/research/object_detection/utils/__pycache__/np_box_mask_list.cpython-310.pyc (deflated 49%)
#   adding: content/models/research/object_detection/utils/__pycache__/learning_schedules.cpython-310.pyc (deflated 62%)
#   adding: content/models/research/object_detection/utils/__pycache__/test_case.cpython-310.pyc (deflated 68%)
#   adding: content/models/research/object_detection/utils/__pycache__/np_box_ops.cpython-310.pyc (deflated 58%)
#   adding: content/models/research/object_detection/utils/__pycache__/context_manager.cpython-310.pyc (deflated 42%)
#   adding: content/models/research/object_detection/utils/__pycache__/np_box_list_ops.cpython-310.pyc (deflated 59%)
#   adding: content/models/research/object_detection/utils/__pycache__/per_image_evaluation.cpython-310.pyc (deflated 72%)
#   adding: content/models/research/object_detection/utils/__pycache__/autoaugment_utils.cpython-310.pyc (deflated 65%)
#   adding: content/models/research/object_detection/utils/__pycache__/tf_version.cpython-310.pyc (deflated 42%)
#   adding: content/models/research/object_detection/utils/__pycache__/np_box_mask_list_ops.cpython-310.pyc (deflated 61%)
#   adding: content/models/research/object_detection/utils/__pycache__/visualization_utils.cpython-310.pyc (deflated 65%)
#   adding: content/models/research/object_detection/utils/__pycache__/json_utils.cpython-310.pyc (deflated 52%)
#   adding: content/models/research/object_detection/utils/__pycache__/static_shape.cpython-310.pyc (deflated 59%)
#   adding: content/models/research/object_detection/utils/__pycache__/np_box_list.cpython-310.pyc (deflated 56%)
#   adding: content/models/research/object_detection/utils/__pycache__/variables_helper.cpython-310.pyc (deflated 55%)
#   adding: content/models/research/object_detection/utils/__pycache__/__init__.cpython-310.pyc (deflated 24%)
#   adding: content/models/research/object_detection/utils/__pycache__/metrics.cpython-310.pyc (deflated 57%)
#   adding: content/models/research/object_detection/utils/__pycache__/ops.cpython-310.pyc (deflated 61%)
#   adding: content/models/research/object_detection/utils/__pycache__/np_mask_ops.cpython-310.pyc (deflated 64%)
#   adding: content/models/research/object_detection/utils/__pycache__/bifpn_utils.cpython-310.pyc (deflated 63%)
#   adding: content/models/research/object_detection/utils/__pycache__/shape_utils.cpython-310.pyc (deflated 62%)
#   adding: content/models/research/object_detection/utils/__pycache__/label_map_util.cpython-310.pyc (deflated 60%)
#   adding: content/models/research/object_detection/utils/__pycache__/object_detection_evaluation.cpython-310.pyc (deflated 70%)
#   adding: content/models/research/object_detection/utils/__pycache__/model_util.cpython-310.pyc (deflated 49%)
#   adding: content/models/research/object_detection/utils/__pycache__/spatial_transform_ops.cpython-310.pyc (deflated 66%)
#   adding: content/models/research/object_detection/utils/__pycache__/target_assigner_utils.cpython-310.pyc (deflated 63%)
#   adding: content/models/research/object_detection/utils/__pycache__/config_util.cpython-310.pyc (deflated 67%)
#   adding: content/models/research/object_detection/utils/target_assigner_utils.py (deflated 74%)
#   adding: content/models/research/object_detection/utils/learning_schedules_test.py (deflated 80%)
#   adding: content/models/research/object_detection/utils/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list.py (deflated 57%)
#   adding: content/models/research/object_detection/utils/ops.py (deflated 74%)
#   adding: content/models/research/object_detection/utils/patch_ops_test.py (deflated 76%)
#   adding: content/models/research/object_detection/utils/context_manager_test.py (deflated 49%)
#   adding: content/models/research/object_detection/utils/tf_version.py (deflated 48%)
#   adding: content/models/research/object_detection/utils/target_assigner_utils_test.py (deflated 79%)
#   adding: content/models/research/object_detection/utils/per_image_evaluation.py (deflated 84%)
#   adding: content/models/research/object_detection/utils/np_box_ops.py (deflated 67%)
#   adding: content/models/research/object_detection/utils/visualization_utils_test.py (deflated 81%)
#   adding: content/models/research/object_detection/utils/model_util.py (deflated 64%)
#   adding: content/models/research/object_detection/utils/test_utils.py (deflated 69%)
#   adding: content/models/research/object_detection/utils/np_box_mask_list_ops_test.py (deflated 79%)
#   adding: content/models/research/object_detection/utils/config_util_test.py (deflated 88%)
#   adding: content/models/research/object_detection/colab_tutorials/ (stored 0%)
#   adding: content/models/research/object_detection/colab_tutorials/eager_few_shot_od_training_tf2_colab.ipynb (deflated 74%)
#   adding: content/models/research/object_detection/colab_tutorials/eager_few_shot_od_training_tflite.ipynb (deflated 74%)
#   adding: content/models/research/object_detection/colab_tutorials/context_rcnn_tutorial.ipynb (deflated 30%)
#   adding: content/models/research/object_detection/colab_tutorials/object_detection_tutorial.ipynb (deflated 76%)
#   adding: content/models/research/object_detection/colab_tutorials/generate_ssd_anchor_box_aspect_ratios_using_k_means_clustering.ipynb (deflated 72%)
#   adding: content/models/research/object_detection/colab_tutorials/convert_odt_model_to_TFLite.ipynb (deflated 73%)
#   adding: content/models/research/object_detection/colab_tutorials/deepmac_colab.ipynb (deflated 72%)
#   adding: content/models/research/object_detection/colab_tutorials/inference_from_saved_model_tf2_colab.ipynb (deflated 74%)
#   adding: content/models/research/object_detection/colab_tutorials/inference_tf2_colab.ipynb (deflated 74%)
#   adding: content/models/research/object_detection/colab_tutorials/centernet_on_device.ipynb (deflated 78%)
#   adding: content/models/research/object_detection/packages/ (stored 0%)
#   adding: content/models/research/object_detection/packages/tf2/ (stored 0%)
#   adding: content/models/research/object_detection/packages/tf2/setup.py (deflated 54%)
#   adding: content/models/research/object_detection/packages/tf1/ (stored 0%)
#   adding: content/models/research/object_detection/packages/tf1/setup.py (deflated 56%)
#   adding: content/models/research/object_detection/model_main.py (deflated 65%)
#   adding: content/models/research/object_detection/exporter_main_v2.py (deflated 68%)
#   adding: content/models/research/object_detection/box_coders/ (stored 0%)
#   adding: content/models/research/object_detection/box_coders/keypoint_box_coder_test.py (deflated 80%)
#   adding: content/models/research/object_detection/box_coders/square_box_coder_test.py (deflated 76%)
#   adding: content/models/research/object_detection/box_coders/square_box_coder.py (deflated 61%)
#   adding: content/models/research/object_detection/box_coders/faster_rcnn_box_coder.py (deflated 61%)
#   adding: content/models/research/object_detection/box_coders/__pycache__/ (stored 0%)
#   adding: content/models/research/object_detection/box_coders/__pycache__/keypoint_box_coder.cpython-310.pyc (deflated 52%)
#   adding: content/models/research/object_detection/box_coders/__pycache__/mean_stddev_box_coder.cpython-310.pyc (deflated 54%)
#   adding: content/models/research/object_detection/box_coders/__pycache__/square_box_coder.cpython-310.pyc (deflated 49%)
#   adding: content/models/research/object_detection/box_coders/__pycache__/__init__.cpython-310.pyc (deflated 23%)
#   adding: content/models/research/object_detection/box_coders/__pycache__/faster_rcnn_box_coder.cpython-310.pyc (deflated 49%)
#   adding: content/models/research/object_detection/box_coders/__init__.py (stored 0%)
#   adding: content/models/research/object_detection/box_coders/mean_stddev_box_coder_test.py (deflated 64%)
#   adding: content/models/research/object_detection/box_coders/mean_stddev_box_coder.py (deflated 62%)
# ...
#   adding: content/models/official/legacy/xlnet/preprocess_classification_data.py (deflated 74%)
#   adding: content/models/official/legacy/xlnet/classifier_utils.py (deflated 64%)
#   adding: content/models/official/legacy/xlnet/preprocess_pretrain_data.py (deflated 72%)
#   adding: content/models/official/legacy/xlnet/squad_utils.py (deflated 73%)
#   adding: content/models/official/legacy/xlnet/preprocess_utils.py (deflated 61%)
#   adding: content/models/official/legacy/xlnet/xlnet_config.py (deflated 64%)
#   adding: content/models/official/legacy/xlnet/preprocess_squad_data.py (deflated 64%)
#   adding: content/models/official/legacy/xlnet/README.md (deflated 60%)
#   adding: content/models/official/legacy/xlnet/run_squad.py (deflated 71%)
#   adding: content/models/official/legacy/xlnet/__init__.py (deflated 37%)
#   adding: content/models/official/legacy/xlnet/run_pretrain.py (deflated 67%)
#   adding: content/models/official/legacy/xlnet/xlnet_modeling.py (deflated 80%)
#   adding: content/models/official/legacy/xlnet/common_flags.py (deflated 66%)
#   adding: content/models/official/legacy/xlnet/data_utils.py (deflated 76%)
#   adding: content/models/official/legacy/xlnet/run_classifier.py (deflated 66%)
#   adding: content/models/official/core/ (stored 0%)
#   adding: content/models/official/core/train_lib.py (deflated 75%)
#   adding: content/models/official/core/train_utils_test.py (deflated 74%)
#   adding: content/models/official/core/config_definitions.py (deflated 65%)
#   adding: content/models/official/core/registry_test.py (deflated 65%)
#   adding: content/models/official/core/savedmodel_checkpoint_manager_test.py (deflated 63%)
#   adding: content/models/official/core/exp_factory.py (deflated 46%)
#   adding: content/models/official/core/input_reader.py (deflated 76%)
#   adding: content/models/official/core/file_writers.py (deflated 64%)
#   adding: content/models/official/core/train_utils.py (deflated 70%)
#   adding: content/models/official/core/tf_example_feature_key_test.py (deflated 55%)
#   adding: content/models/official/core/tf_example_builder.py (deflated 69%)
#   adding: content/models/official/core/export_base_test.py (deflated 68%)
#   adding: content/models/official/core/base_task.py (deflated 70%)
#   adding: content/models/official/core/train_lib_test.py (deflated 80%)
#   adding: content/models/official/core/actions_test.py (deflated 68%)
#   adding: content/models/official/core/base_trainer_test.py (deflated 75%)
#   adding: content/models/official/core/file_writers_test.py (deflated 57%)
#   adding: content/models/official/core/task_factory.py (deflated 55%)
#   adding: content/models/official/core/tf_example_builder_test.py (deflated 78%)
#   adding: content/models/official/core/savedmodel_checkpoint_manager.py (deflated 70%)
#   adding: content/models/official/core/__init__.py (deflated 55%)
#   adding: content/models/official/core/base_trainer.py (deflated 73%)
#   adding: content/models/official/core/registry.py (deflated 68%)
#   adding: content/models/official/core/tf_example_feature_key.py (deflated 53%)
#   adding: content/models/official/core/actions.py (deflated 69%)
#   adding: content/models/official/core/export_base.py (deflated 62%)
#   adding: content/models/official/core/test_utils.py (deflated 56%)
#   adding: content/models/.github/ (stored 0%)
#   adding: content/models/.github/workflows/ (stored 0%)
#   adding: content/models/.github/workflows/ci.yml (deflated 53%)
#   adding: content/models/.github/workflows/stale.yaml (deflated 62%)
#   adding: content/models/.github/README_TEMPLATE.md (deflated 60%)
#   adding: content/models/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/models/.github/ISSUE_TEMPLATE/config.yml (stored 0%)
#   adding: content/models/.github/ISSUE_TEMPLATE/20-official-feature-request-issue.md (deflated 40%)
#   adding: content/models/.github/ISSUE_TEMPLATE/50-research-feature-request-issue.md (deflated 40%)
#   adding: content/models/.github/ISSUE_TEMPLATE/10-official-documentation-issue.md (deflated 37%)
#   adding: content/models/.github/ISSUE_TEMPLATE/60-questions-help-issue.md (deflated 38%)
#   adding: content/models/.github/ISSUE_TEMPLATE/00-official-bug-report-issue.md (deflated 50%)
#   adding: content/models/.github/ISSUE_TEMPLATE/40-research-documentation-issue.md (deflated 38%)
#   adding: content/models/.github/ISSUE_TEMPLATE/30-research-bug-report-issue.md (deflated 50%)
#   adding: content/models/.github/PULL_REQUEST_TEMPLATE.md (deflated 55%)
#   adding: content/models/.github/scripts/ (stored 0%)
#   adding: content/models/.github/scripts/pylint.sh (deflated 57%)
#   adding: content/models/.github/bot_config.yml (deflated 43%)
#   adding: content/models/orbit/ (stored 0%)
#   adding: content/models/orbit/runner.py (deflated 59%)
#   adding: content/models/orbit/actions/ (stored 0%)
#   adding: content/models/orbit/actions/export_saved_model_test.py (deflated 82%)
#   adding: content/models/orbit/actions/conditional_action.py (deflated 52%)
#   adding: content/models/orbit/actions/conditional_action_test.py (deflated 47%)
#   adding: content/models/orbit/actions/new_best_metric.py (deflated 66%)
#   adding: content/models/orbit/actions/__init__.py (deflated 55%)
#   adding: content/models/orbit/actions/save_checkpoint_if_preempted.py (deflated 58%)
#   adding: content/models/orbit/actions/export_saved_model.py (deflated 61%)
#   adding: content/models/orbit/actions/new_best_metric_test.py (deflated 72%)
#   adding: content/models/orbit/utils/ (stored 0%)
#   adding: content/models/orbit/utils/common_test.py (deflated 44%)
#   adding: content/models/orbit/utils/tpu_summaries.py (deflated 62%)
#   adding: content/models/orbit/utils/summary_manager_interface.py (deflated 56%)
#   adding: content/models/orbit/utils/common.py (deflated 58%)
#   adding: content/models/orbit/utils/tpu_summaries_test.py (deflated 69%)
#   adding: content/models/orbit/utils/loop_fns.py (deflated 70%)
#   adding: content/models/orbit/utils/__init__.py (deflated 52%)
#   adding: content/models/orbit/utils/epoch_helper.py (deflated 58%)
#   adding: content/models/orbit/utils/summary_manager.py (deflated 63%)
#   adding: content/models/orbit/controller.py (deflated 72%)
#   adding: content/models/orbit/LICENSE (deflated 65%)
#   adding: content/models/orbit/examples/ (stored 0%)
#   adding: content/models/orbit/examples/single_task/ (stored 0%)
#   adding: content/models/orbit/examples/single_task/single_task_trainer.py (deflated 61%)
#   adding: content/models/orbit/examples/single_task/single_task_evaluator.py (deflated 57%)
#   adding: content/models/orbit/examples/single_task/single_task_evaluator_test.py (deflated 55%)
#   adding: content/models/orbit/examples/single_task/single_task_trainer_test.py (deflated 52%)
#   adding: content/models/orbit/examples/single_task/__init__.py (deflated 37%)
#   adding: content/models/orbit/examples/__init__.py (deflated 37%)
#   adding: content/models/orbit/standard_runner_test.py (deflated 72%)
#   adding: content/models/orbit/README.md (deflated 40%)
#   adding: content/models/orbit/standard_runner.py (deflated 74%)
#   adding: content/models/orbit/__init__.py (deflated 54%)
#   adding: content/models/orbit/controller_test.py (deflated 86%)
#   adding: content/models/docs/ (stored 0%)
#   adding: content/models/docs/vision/ (stored 0%)
#   adding: content/models/docs/vision/image_classification.ipynb (deflated 76%)
#   adding: content/models/docs/vision/semantic_segmentation.ipynb (deflated 76%)
#   adding: content/models/docs/vision/_toc.yaml (deflated 61%)
#   adding: content/models/docs/vision/instance_segmentation.ipynb (deflated 77%)
#   adding: content/models/docs/vision/object_detection.ipynb (deflated 76%)
#   adding: content/models/docs/nlp/ (stored 0%)
#   adding: content/models/docs/nlp/customize_encoder.ipynb (deflated 79%)
#   adding: content/models/docs/nlp/_guide_toc.yaml (deflated 40%)
#   adding: content/models/docs/nlp/index.ipynb (deflated 79%)
#   adding: content/models/docs/nlp/fine_tune_bert.ipynb (deflated 78%)
#   adding: content/models/docs/nlp/load_lm_ckpts.ipynb (deflated 84%)
#   adding: content/models/docs/nlp/decoding_api.ipynb (deflated 76%)
#   adding: content/models/docs/README.md (deflated 51%)
#   adding: content/models/docs/index.md (deflated 64%)
#   adding: content/models/docs/orbit/ (stored 0%)
#   adding: content/models/docs/orbit/index.ipynb (deflated 76%)
#   adding: content/tensorflow-object-detection-faster-rcnn/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/ORIG_HEAD (deflated 2%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/refs/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/refs/heads/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/refs/heads/master (deflated 2%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/refs/remotes/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/refs/tags/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/info/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/info/exclude (deflated 28%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/hooks/update.sample (deflated 68%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/description (deflated 14%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/packed-refs (deflated 19%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/index (deflated 41%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/objects/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/objects/pack/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/objects/pack/pack-381bbb44765a67638815efeff848ef950b4d6dce.idx (deflated 2%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/objects/pack/pack-381bbb44765a67638815efeff848ef950b4d6dce.pack (deflated 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/objects/info/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/config (deflated 34%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/FETCH_HEAD (deflated 15%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/branches/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/refs/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/refs/heads/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/refs/heads/master (deflated 30%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/refs/remotes/origin/HEAD (deflated 30%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/logs/HEAD (deflated 30%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.git/HEAD (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/resize_images.py (deflated 63%)
#   adding: content/tensorflow-object-detection-faster-rcnn/generate_tfrecord.py (deflated 67%)
#   adding: content/tensorflow-object-detection-faster-rcnn/xml_to_csv.py (deflated 63%)
#   adding: content/tensorflow-object-detection-faster-rcnn/LICENSE (deflated 50%)
#   adding: content/tensorflow-object-detection-faster-rcnn/Tutorial_Mobilenet.ipynb (deflated 35%)
#   adding: content/tensorflow-object-detection-faster-rcnn/requirements.txt (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/local_inference_test.py (deflated 67%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/test/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/test/fire.tfrecord (deflated 2%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/test/fire_label_map.pbtxt (deflated 28%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/train/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/train/fire.tfrecord (deflated 2%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt (deflated 28%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/.gitignore (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/data/FYI.txt (deflated 2%)
#   adding: content/tensorflow-object-detection-faster-rcnn/Tutorial_Faster_RCNN.ipynb (deflated 26%)
#   adding: content/tensorflow-object-detection-faster-rcnn/.gitignore (deflated 3%)
#   adding: content/tensorflow-object-detection-faster-rcnn/README.md (deflated 62%)
#   adding: content/tensorflow-object-detection-faster-rcnn/tensorflow_object_detection_training_colab.ipynb (deflated 31%)
#   adding: content/tensorflow-object-detection-faster-rcnn/deploy/ (stored 0%)
#   adding: content/tensorflow-object-detection-faster-rcnn/deploy/deploy_utils.py (deflated 51%)
#   adding: content/tensorflow-object-detection-faster-rcnn/deploy/.gitignore (deflated 4%)
#   adding: content/tensorflow-object-detection-faster-rcnn/deploy/openvino_convert_tf_object_detection.ipynb (deflated 30%)
#   adding: content/tensorflow-object-detection-faster-rcnn/deploy/openvino_inference_benchmark.py (deflated 60%)
#   adding: content/tensorflow-object-detection-faster-rcnn/local_inference_test.ipynb (deflated 25%)
#   adding: content/training/ (stored 0%)
#   adding: content/training/checkpoint (deflated 54%)
#   adding: content/training/ckpt-2.index (deflated 82%)
#   adding: content/training/ckpt-1.index (deflated 81%)
#   adding: content/training/train/ (stored 0%)
#   adding: content/training/train/events.out.tfevents.1701798822.f923db285da9.5516.0.v2 (deflated 0%)
#   adding: content/training/ckpt-2.data-00000-of-00001 (deflated 7%)
#   adding: content/training/ckpt-1.data-00000-of-00001 (deflated 8%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)

# %% [markdown]
# ### OPTIONAL: Download the `label_map.pbtxt` file

# %%
from google.colab import files
files.download(label_map_pbtxt_fname)

# %% [markdown]
# ### OPTIONAL: Download the modified pipline file
# If you plan to use OpenVINO toolkit to convert the `.pb` file to inference faster on Intel's hardware (CPU/GPU, Movidius, etc.)

# %%
files.download(pipeline_fname)

# %%
# !tar cfz fine_tuned_model.tar.gz fine_tuned_model
from google.colab import files
files.download('fine_tuned_model.tar.gz')
# Out:
# ^C

# %% [markdown]
# ## Run inference test
# Test with images in repository `tensorflow-object-detection/test` directory.
#
# **To test with your own images, you need to place your images inside the `test` directory in this Colab notebook!** More on this below.

# %%
# !cp -r /content/test/test/ /content/tensorflow-object-detection-faster-rcnn/
# Out:
# cp: cannot stat '/content/test/test/': No such file or directory

# %%
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = saved_model_pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname
print(PATH_TO_LABELS)

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
PATH_TO_TEST_IMAGES_DIR =  os.path.join(repo_dir_path, "test")

assert os.path.isfile(saved_model_pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(TEST_IMAGES_PATH, "*.*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
print(TEST_IMAGE_PATHS)
# Out:
# /content/tensorflow-object-detection-faster-rcnn/data/train/fire_label_map.pbtxt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-8f2a3bbfb882> in <cell line: 16>()
#      14 assert os.path.isfile(saved_model_pb_fname)
#      15 assert os.path.isfile(PATH_TO_LABELS)
# ---> 16 TEST_IMAGE_PATHS = glob.glob(os.path.join(TEST_IMAGES_PATH, "*.*"))
#      17 assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
#      18 print(TEST_IMAGE_PATHS)
#
# NameError: name 'TEST_IMAGES_PATH' is not defined

# %%
# !ls /content/tensorflow-object-detection-faster-rcnn/

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops


# This is needed to display the images.
# %matplotlib inline


from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict

# %%
# Output images not showing? Run this cell again, and try the cell above
# This is needed to display the images.
# %matplotlib inline

# %%
# Limited displayed images to 5 to reduce memory
count = 5
for i, image_path in enumerate(TEST_IMAGE_PATHS):
    if i > count:
        break
    image = Image.open(image_path)
    # the array based representation of the image will be used later in order to prepare the
    # result image with boxes and labels on it.
    image_np = load_image_into_numpy_array(image)
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np, detection_graph)
    # Visualization of the results of a detection.
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks'),
        use_normalized_coordinates=True,
        line_thickness=8)
    plt.figure(figsize=IMAGE_SIZE)
    plt.imshow(image_np)

# %% [markdown]
# # 3. Convert

# %% [markdown]
# With our model trained, it's time to convert our graph to .tflite!

# %%
# %ls /content/models/research/fine_tuned_model/tflite

# %%
# !tflite_convert \
  --input_shape=1,224,224,3 \
  --input_arrays=normalized_input_image_tensor \
  --output_arrays=MobilenetV1/Predictions/Softmax \
  --allow_custom_ops \
  --graph_def_file=/content/models/research/fine_tuned_model/tflite/tflite_graph.pb \
  --output_file="/content/models/research/fine_tuned_model/final_model.tflite"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import tensorflow as tf

# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter('/content/drive/MyDrive/final_model.tflite')
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test model on random input data.
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)

# %%
# Change the final TFLite destination here
# !cp /content/models/research/fine_tuned_model/final_model.tflite "/content/drive/My Drive/"

# %% [markdown]
# Your TFLite file is now in your Drive as "final_model.tflite", ready to use with your project on-device! For specific device tutorials, check out the official TensorFlow Lite [Android Demo](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/android), [iOS Demo](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/ios), or [Raspberry Pi Demo](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi). [link text](https://)
